# %% [markdown]
# # Packages Install

# %% [markdown]
# ## Mecab-ko Install

# %%
# !pwd
# Out:
# /Users/nayo/dl/nlp_pjt

# %%
ls ../mecab
# Out:
# eKoNLPy/

# %%
#!mkdir mecab

# %%
# !wget -O ../mecab/mecab-0.996-ko-0.9.2.tar.gz https://bitbucket.org/eunjeon/mecab-ko/downloads/mecab-0.996-ko-0.9.2.tar.gz
# Out:
# --2022-02-18 15:12:42--  https://bitbucket.org/eunjeon/mecab-ko/downloads/mecab-0.996-ko-0.9.2.tar.gz
# bitbucket.org (bitbucket.org) 해석 중... 104.192.141.1
# 다음으로 연결 중: bitbucket.org (bitbucket.org)|104.192.141.1|:443... 연결했습니다.
# HTTP 요청을 보냈습니다. 응답 기다리는 중... 302 Found
# 위치: https://bbuseruploads.s3.amazonaws.com/eunjeon/mecab-ko/downloads/mecab-0.996-ko-0.9.2.tar.gz?Signature=5FgOQloueGzhhZNUZQQEPbuWM2Y%3D&Expires=1645166563&AWSAccessKeyId=AKIA6KOSE3BNA7WTAGHW&versionId=null&response-content-disposition=attachment%3B%20filename%3D%22mecab-0.996-ko-0.9.2.tar.gz%22&response-content-encoding=None [따라감]
# --2022-02-18 15:12:43--  https://bbuseruploads.s3.amazonaws.com/eunjeon/mecab-ko/downloads/mecab-0.996-ko-0.9.2.tar.gz?Signature=5FgOQloueGzhhZNUZQQEPbuWM2Y%3D&Expires=1645166563&AWSAccessKeyId=AKIA6KOSE3BNA7WTAGHW&versionId=null&response-content-disposition=attachment%3B%20filename%3D%22mecab-0.996-ko-0.9.2.tar.gz%22&response-content-encoding=None
# bbuseruploads.s3.amazonaws.com (bbuseruploads.s3.amazonaws.com) 해석 중... 52.217.80.100
# 다음으로 연결 중: bbuseruploads.s3.amazonaws.com (bbuseruploads.s3.amazonaws.com)|52.217.80.100|:443... 연결했습니다.
# HTTP 요청을 보냈습니다. 응답 기다리는 중... 200 OK
# 길이: 1414979 (1.3M) [application/x-tar]
# 저장 위치: `../mecab/mecab-0.996-ko-0.9.2.tar.gz'
#
# ../mecab/mecab-0.99 100%[===================>]   1.35M  1.05MB/s    /  1.3s
#
# 2022-02-18 15:12:45 (1.05 MB/s) - `../mecab/mecab-0.996-ko-0.9.2.tar.gz' 저장함 [1414979/1414979]

# %%
# !tar xzvf ../mecab/mecab-0.996-ko-0.9.2.tar.gz -C ../mecab

# %% [markdown]
# ### **terminal에서 실행**

# %%
# !cd ../mecab/mecab-0.996-ko-0.9.2
# ./configure
# make
# sudo make install

# %% [markdown]
# ## Mecab-dict Install

# %%
# !wget -O ./mecab/mecab-ko-dic-2.1.1-20180720.tar.gz https://bitbucket.org/eunjeon/mecab-ko-dic/downloads/mecab-ko-dic-2.1.1-20180720.tar.gz
# Out:
# --2022-02-12 19:26:54--  https://bitbucket.org/eunjeon/mecab-ko-dic/downloads/mecab-ko-dic-2.1.1-20180720.tar.gz
# bitbucket.org (bitbucket.org) 해석 중... 104.192.141.1
# 다음으로 연결 중: bitbucket.org (bitbucket.org)|104.192.141.1|:443... 연결했습니다.
# HTTP 요청을 보냈습니다. 응답 기다리는 중... 302 Found
# 위치: https://bbuseruploads.s3.amazonaws.com/a4fcd83e-34f1-454e-a6ac-c242c7d434d3/downloads/b5a0c703-7b64-45ed-a2d7-180e962710b6/mecab-ko-dic-2.1.1-20180720.tar.gz?Signature=%2FW40c%2Fe1oJOLcZDEc8YdIcGMoDc%3D&Expires=1644663418&AWSAccessKeyId=AKIA6KOSE3BNA7WTAGHW&versionId=tzyxc1TtnZU_zEuaaQDGN4F76hPDpyFq&response-content-disposition=attachment%3B%20filename%3D%22mecab-ko-dic-2.1.1-20180720.tar.gz%22&response-content-encoding=None [따라감]
# --2022-02-12 19:26:55--  https://bbuseruploads.s3.amazonaws.com/a4fcd83e-34f1-454e-a6ac-c242c7d434d3/downloads/b5a0c703-7b64-45ed-a2d7-180e962710b6/mecab-ko-dic-2.1.1-20180720.tar.gz?Signature=%2FW40c%2Fe1oJOLcZDEc8YdIcGMoDc%3D&Expires=1644663418&AWSAccessKeyId=AKIA6KOSE3BNA7WTAGHW&versionId=tzyxc1TtnZU_zEuaaQDGN4F76hPDpyFq&response-content-disposition=attachment%3B%20filename%3D%22mecab-ko-dic-2.1.1-20180720.tar.gz%22&response-content-encoding=None
# bbuseruploads.s3.amazonaws.com (bbuseruploads.s3.amazonaws.com) 해석 중... 52.216.250.196
# 다음으로 연결 중: bbuseruploads.s3.amazonaws.com (bbuseruploads.s3.amazonaws.com)|52.216.250.196|:443... 연결했습니다.
# HTTP 요청을 보냈습니다. 응답 기다리는 중... 200 OK
# 길이: 49775061 (47M) [application/x-tar]
# 저장 위치: `./mecab/mecab-ko-dic-2.1.1-20180720.tar.gz'
#
# ./mecab/mecab-ko-di 100%[===================>]  47.47M   697KB/s    /  1m 43s
#
# 2022-02-12 19:28:40 (470 KB/s) - `./mecab/mecab-ko-dic-2.1.1-20180720.tar.gz' 저장함 [49775061/49775061]

# %%
# !tar xzvf ./mecab/mecab-ko-dic-2.1.1-20180720.tar.gz -C ./mecab

# %% [markdown]
# ### **terminal에서 실행**

# %%
# cd mecab-ko-dic-2.1.1-20180720
# autoreconf
# ./configure~
# make
# sudo make install

# %% [markdown]
# ## Mecab-python Install

# %%
git clone https://bitbucket.org/eunjeon/mecab-python-0.996.git
cd mecab-python-0.996
python setup.py build
python setup.py install
# Out:
# 'mecab-python-0.996'에 복제합니다...
# 오브젝트 묶음 푸는 중: 100% (17/17), 59.65 KiB | 333.00 KiB/s, 완료.

# %% [markdown]
# ## KoNLPy Install

# %%
pip install konlpy
# Out:
# Collecting konlpy
#   Using cached konlpy-0.6.0-py2.py3-none-any.whl (19.4 MB)
# Collecting lxml>=4.1.0
#   Downloading lxml-4.7.1.tar.gz (3.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 9.2 MB/s eta 0:00:000:00:0136m0:00:01:01
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy>=1.6 in /opt/homebrew/Caskroom/miniforge/base/envs/tf25/lib/python3.8/site-packages (from konlpy) (1.22.2)
# Collecting JPype1>=0.7.0
#   Downloading JPype1-1.3.0.tar.gz (820 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 820.3/820.3 KB 8.7 MB/s eta 0:00:00m eta 0:00:010:01
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: JPype1, lxml
#   Building wheel for JPype1 (setup.py) ... done
#   Created wheel for JPype1: filename=JPype1-1.3.0-cp38-cp38-macosx_11_0_arm64.whl size=368049 sha256=9fa17621a7c6bd798763fecea76c78fed21890e94f9001ca5d1a988a162300d5
#   Stored in directory: /Users/thkim/Library/Caches/pip/wheels/d7/a8/84/c198bb525f88f975101b84ef43cc8e3cb4261831d8ea73dc3b
#   Building wheel for lxml (setup.py) ... done
#   Created wheel for lxml: filename=lxml-4.7.1-cp38-cp38-macosx_11_0_arm64.whl size=1482710 sha256=5a78a8bd2ff192241d8e361f13d65eecd3bfa1b3494a382f842451637ca5a637
#   Stored in directory: /Users/thkim/Library/Caches/pip/wheels/c7/d8/ac/9c62a8804498b75b652f0cfbe020c93ae3f7265a9bbb40cee9
# Successfully built JPype1 lxml
# Installing collected packages: JPype1, lxml, konlpy
# Successfully installed JPype1-1.3.0 konlpy-0.6.0 lxml-4.7.1
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## eKoNLPy Install
# File path : https://github.com/entelecheia/eKoNLPy.git
#
# **Terminal : Mecab Install path에서 실행**
# <br/>
# [reference: https://m.blog.naver.com/PostView.naver?isHttpsRedirect=true&blogId=yejin7676&logNo=222024761669](https://m.blog.naver.com/PostView.naver?isHttpsRedirect=true&blogId=yejin7676&logNo=222024761669)

# %%
git clone https://github.com/entelecheia/eKoNLPy.git
cd ./eKoNLPy
pip install .

# %% [markdown]
# ## Finance Data Reader Package Install

# %%
# !pip install finance-datareader

# %%
# Finance Data Reader Update
# !pip install -U finance-datareader

# %% [markdown]
# ## Mecab compile test

# %%
from ekonlpy.tag import Mecab

mecab = Mecab()
sent = "SK하이닉스 오늘 얼마야?"
mecab.morphs(sent)
# Out:
# ['SK하이닉스', '오늘', '얼마', '야', '?']

# %% [markdown]
# # Load Stock Data

# %% [markdown]
# ### packages Import

# %%
import FinanceDataReader as fdr
import pandas as pd
import numpy as np

fdr.__version__
# Out:
# '0.9.31'

# %% [markdown]
# ### Stock List Data Load

# %%
df_krx = fdr.StockListing('KRX')
print(df_krx.shape)
df_krx.head()
# Out:
# (7672, 10)
#    Symbol  Market    Name Sector Industry ListingDate SettleMonth  \
# 0  060310  KOSDAQ      3S    NaN      NaN         NaT         NaN
# 1  095570   KOSPI  AJ네트웍스    NaN      NaN         NaT         NaN
# 2  006840   KOSPI   AK홀딩스    NaN      NaN         NaT         NaN
# 3  054620  KOSDAQ  APS홀딩스    NaN      NaN         NaT         NaN
# 4  265520  KOSDAQ   AP시스템    NaN      NaN         NaT         NaN
#
#   Representative HomePage Region
# 0            NaN      NaN    NaN
# 1            NaN      NaN    NaN
# 2            NaN      NaN    NaN
# 3            NaN      NaN    NaN
# 4            NaN      NaN    NaN

# %%
df_kospi = fdr.StockListing('KOSPI')
print(df_kospi.shape)
df_kospi.head()
# Out:
# (5980, 10)
#    Symbol Market               Name Sector Industry ListingDate SettleMonth  \
# 1  095570  KOSPI             AJ네트웍스    NaN      NaN         NaT         NaN
# 2  006840  KOSPI              AK홀딩스    NaN      NaN         NaT         NaN
# 6  152100  KOSPI        ARIRANG 200    NaN      NaN         NaT         NaN
# 7  295820  KOSPI    ARIRANG 200동일가중    NaN      NaN         NaT         NaN
# 8  253150  KOSPI  ARIRANG 200선물레버리지    NaN      NaN         NaT         NaN
#
#   Representative HomePage Region
# 1            NaN      NaN    NaN
# 2            NaN      NaN    NaN
# 6            NaN      NaN    NaN
# 7            NaN      NaN    NaN
# 8            NaN      NaN    NaN

# %% [markdown]
# ### Stock Price Data Load

# %%
import time
fdr.DataReader("060310",'2020-01-01', time.strftime(("%Y-%m-%d")))
# Out:
#             Open  High   Low  Close  Volume    Change
# Date
# 2020-01-02  2820  2845  2780   2795  131742 -0.008865
# 2020-01-03  2795  2825  2775   2810  100374  0.005367
# 2020-01-06  2800  2805  2650   2685  201779 -0.044484
# 2020-01-07  2685  2745  2685   2745   62241  0.022346
# 2020-01-08  2720  2745  2580   2585  203909 -0.058288
# ...          ...   ...   ...    ...     ...       ...
# 2022-02-22  3005  3145  3000   3095  163319 -0.017460
# 2022-02-23  3115  3135  3035   3095  193360  0.000000
# 2022-02-24  3090  3095  2910   2925  156778 -0.054927
# 2022-02-25  2955  3070  2865   2990  120789  0.022222
# 2022-02-28  2950  3085  2950   3070  142209  0.026756
#
# [534 rows x 6 columns]

# %%
stock_df = pd.read_csv("./data/stock_df.csv")
stk_list = stock_df.name.to_list().copy()
print(stk_list[:5])
print('stock 데이터 내 기업의 수: {}'.format(len(stk_list)))
# Out:
# ['AJ네트웍스', 'AK홀딩스', 'BGF', 'BGF리테일', 'BNK금융지주']
# stock 데이터 내 기업의 수: 2485

# %% [markdown]
# ## 종목 이름 사전 추가

# %% [markdown]
# **mecab.add_dictionary 오류로 인해 물리적으로 사전 추가**
# - /Users/thkim/Documents/git/chatbot_stock/mecab/mecab-ko-dic-2.1.1-20180720/user-dic/nnp.csv

# %%
# 추가한 mecab dictionary 가 정상적으로 작동하는지 테스트
mecab.morphs('SK하이닉스 종가 얼마야?')
# Out:
# ['SK하이닉스', '종가', '얼마', '야', '?']

# %% [markdown]
# ### 사전 추가 항목 형태 맞추기
# - 기업명의 종성의 받침 여부 (받침 O : T / 받침 X : F)

# %%
from jamo import h2j, j2hcj 


stock = stk_list.copy()
# print(len(stock))
def concat_word(x):
    jamo_str = j2hcj(h2j(x))
    
    if jamo_str[-1] in ['ㄱ', 'ㄲ', 'ㄳ', 'ㄴ', 'ㄵ', 'ㄶ', 'ㄷ', 'ㄹ', 'ㄺ', 'ㄻ', 'ㄼ', 'ㄽ', 'ㄾ', 'ㄿ', 'ㅀ', 'ㅁ', 'ㅂ', 'ㅄ', 'ㅅ', 'ㅆ', 'ㅇ', 'ㅈ', 'ㅊ', 'ㅋ', 'ㅌ', 'ㅍ', 'ㅎ']:
        x = x + ",,,,NNP,*,{0},{1},*,*,*,*,*".format("T",x)
    else:
        x = x + ",,,,NNP,*,{0},{1},*,*,*,*,*".format("F",x)

    return x

stock = pd.Series(stock)
stock = stock.apply(lambda x: concat_word(x))

print(len(stock))
stock[:10]
# Out:
# 2485
# 0        AJ네트웍스,,,,NNP,*,F,AJ네트웍스,*,*,*,*,*
# 1          AK홀딩스,,,,NNP,*,F,AK홀딩스,*,*,*,*,*
# 2              BGF,,,,NNP,*,F,BGF,*,*,*,*,*
# 3        BGF리테일,,,,NNP,*,T,BGF리테일,*,*,*,*,*
# 4      BNK금융지주,,,,NNP,*,F,BNK금융지주,*,*,*,*,*
# 5              BYC,,,,NNP,*,F,BYC,*,*,*,*,*
# 6            BYC우,,,,NNP,*,F,BYC우,*,*,*,*,*
# 7                CJ,,,,NNP,*,F,CJ,*,*,*,*,*
# 8        CJ CGV,,,,NNP,*,F,CJ CGV,*,*,*,*,*
# 9    CJ4우(전환),,,,NNP,*,F,CJ4우(전환),*,*,*,*,*
# dtype: object

# %% [markdown]
# # 데이터 수집 및 생성

# %% [markdown]
# ## 유사 종목 데이터 (similarity_df)

# %% [markdown]
# ### 종목별 질문 생성 함수 (training 용도)

# %%
def generate_sim_question(stock_names):
    question = []
    for stk in stock_names:
        s1 = stk + "의 유사 종목"
        s2 = stk + "의 유사 종목 보여줘"
        s3 = stk + "의 유사 종목 알려줘"
        s4 = stk + "의 유사 종목 열람"
        s5 = stk + "와 유사 종목은 뭐가 있어?"
        s6 = stk + "의 유사 종목은 모야"
        s7 = stk + "의 유사 종목은 모야?"
        s8 = stk + "와 비슷한 항목"
        s9 = stk + "와 비슷한 항목 보여줘"
        s10 = stk + "와 비슷한 항목 알려줘"
        s11 = stk + "와 비슷한 항목 열람"
        s12 = stk + "랑 비슷한 항목은 뭐가 있어?"
        s13 = stk + "랑 비슷한 항목 모야"
        s14 = stk + "랑 비슷한 항목 모야?"
        s15 = stk + "랑 비슷한 항목이 모야"
        s16 = stk + "랑 비슷한 항목이 모야?"
        s17 = stk + "랑 비슷한 항목은 뭐가 있어?"
        s18 = stk + "와 비슷한 주식"
        s19 = stk + "와 비슷한 주식 보여줘"
        s20 = stk + "와 비슷한 주식 알려줘"
        s21 = stk + "와 비슷한 주식 열람"
        s22 = stk + "랑 비슷한 주식은 뭐가 있어?"
        s23 = stk + "랑 비슷한 주식 모야"
        s24 = stk + "랑 비슷한 주식 모야?"
        s25 = stk + "랑 비슷한 주식이 모야"
        s26 = stk + "랑 비슷한 주식이 모야?"
        question = question + [s1, s2, s3, s4, s5, s6, s7, s8, s9, s10, s11, s12, s13, s14, s15, s16, s17, s18, s19, s20, s21, s22, s23, s24, s25, s26]
    
    return question
similarity_questions = generate_sim_question(stk_list)
len(similarity_questions)
# Out:
# 64610

# %% [markdown]
# ### (종목명 제외) 질문에 대한 형태소 저장

# %%
sim_question = generate_sim_question(['네이버'])
print(sim_question[:5])
# Out:
# ['네이버의 유사 종목', '네이버의 유사 종목 보여줘', '네이버의 유사 종목 알려줘', '네이버의 유사 종목 열람', '네이버와 유사 종목은 뭐가 있어?']

# %%
tokenized_question = [mecab.morphs(question) for question in sim_question]
tokenized_question[:5]
# Out:
# [['네이버', '의', '유사', '종목'],
#  ['네이버', '의', '유사', '종목', '보여줘'],
#  ['네이버', '의', '유사', '종목', '알려줘'],
#  ['네이버', '의', '유사', '종목', '열람'],
#  ['네이버', '와', '유사', '종목', '은', '뭐', '가', '있', '어', '?']]

# %%
similarity_not_stock_name_list = []
for i in tokenized_question:
    for word in i:
        if word != '네이버':
            similarity_not_stock_name_list.append(word)
similarity_not_stock_name_list[:20]
# Out:
# ['의',
#  '유사',
#  '종목',
#  '의',
#  '유사',
#  '종목',
#  '보여줘',
#  '의',
#  '유사',
#  '종목',
#  '알려줘',
#  '의',
#  '유사',
#  '종목',
#  '열람',
#  '와',
#  '유사',
#  '종목',
#  '은',
#  '뭐']

# %%
similarity_df = pd.DataFrame(zip(similarity_questions, ['유사기업']*len(similarity_questions)), columns = ['question', 'intent'])
similarity_df
# Out:
#                     question intent
# 0              AJ네트웍스의 유사 종목   유사기업
# 1          AJ네트웍스의 유사 종목 보여줘   유사기업
# 2          AJ네트웍스의 유사 종목 알려줘   유사기업
# 3           AJ네트웍스의 유사 종목 열람   유사기업
# 4      AJ네트웍스와 유사 종목은 뭐가 있어?   유사기업
# ...                      ...    ...
# 64605     힘스랑 비슷한 주식은 뭐가 있어?   유사기업
# 64606          힘스랑 비슷한 주식 모야   유사기업
# 64607         힘스랑 비슷한 주식 모야?   유사기업
# 64608         힘스랑 비슷한 주식이 모야   유사기업
# 64609        힘스랑 비슷한 주식이 모야?   유사기업
#
# [64610 rows x 2 columns]

# %% [markdown]
# ## 주가 데이터 (price_df)
# - 주가 데이터 요청 시, 현재 가격을 실시간으로 불러들여 답변
# - or 요청 당일 시가와 전날 종가를 DB에 저장해놓고 답변
#     - 요청 시기가 장 마감 이후인 경우 당일 종가 답변 가능
#     - 문제! 고가, 저가를 요청할 경우 DB에 저장하는 방식으로는 전날 데이터밖에 답변 못함

# %%
import FinanceDataReader as fdr
import time

fdr.DataReader("005930",time.strftime(("%Y"))).tail(5)
# Out:
#              Open   High    Low  Close    Volume    Change
# Date
# 2022-02-22  73000  73400  72800  73400  11692469 -0.010782
# 2022-02-23  73800  73800  72800  73000  10397964 -0.005450
# 2022-02-24  72300  72300  71300  71500  15759283 -0.020548
# 2022-02-25  72100  72600  71900  71900  13168484  0.005594
# 2022-02-28  71100  72100  71000  72100  17640567  0.002782

# %% [markdown]
# ### 종목별 주가 질문 생성 함수 (training 용도)

# %%
def generate_stock_price_question(stock_name):
    question = []
    for stk in stock_name:
        s1 = stk + " 얼마야?"
        s2 = stk + " 요즘 얼마야?"
        s3 = stk + " 가격"
        s4 = stk + " 시가"
        s5 = stk + " 종가"
        s6 = stk + " 고가"
        s7 = stk + " 저가"
        s8 = stk + " 변화율"
        s9 = stk + " 가격이 어떻게 돼?"

        s10 = stk + " 고가가 어떻게 돼?"
        s11 = stk + " 고가 얼마야?"
        s12 = stk + " 종가 얼마냐"
        s13 = stk + " 고가 보여줘"
        s14 = stk + " 저가 알려줘"
        s15 = stk + " 고가 말해"

        s16 = stk + " 시가가 어떻게 돼?"
        s17 = stk + " 시가 얼마야?"
        s18 = stk + " 시가 얼마냐"
        s19 = stk + " 종가 보여줘"
        s20 = stk + " 저가 알려줘"
        s21 = stk + " 시가 말해"

        s22 = stk + " 변화율은?"
        s23 = stk + " 변화율 몇이야?"
        s24 = stk + " 변화율이 몇이야?"
        s25 = stk + " 변화율 얼마야?"
        s26 = stk + " 변화율 궁금해"
        s27 = stk + " 변화율이 궁금해?"
        
        s28 = stk + " 그래프"
        s29 = stk + " 그래프 보여줘"
        s30 = stk + " 그래프 띄워줘"
        s31 = stk + " 그래프 띄워"
        s32 = stk + " 그래프 줘"
        s33 = stk + " 그래프 어때?"
        s34 = stk + " 그래프 어떻게 돼?"
        s35 = stk + " 그래프 궁금해"
        s36 = stk + " 그래프 보고싶어"
        
        s37 = stk + " 차트"
        s38 = stk + " 차트 보여줘"
        s39 = stk + " 차트 띄워줘"
        s40 = stk + " 차트 띄워"
        s41 = stk + " 차트 줘"
        s42 = stk + " 차트 어때?"
        s43 = stk + " 차트 어떻게 돼?"
        s44 = stk + " 차트 궁금해"
        s45 = stk + " 차트 보고싶어"
        
        s46 = stk + " 가격 추이"
        s47 = stk + " 가격 추이 보여줘"
        s48 = stk + " 가격 추이 띄워줘"
        s49 = stk + " 가격 추이 띄워"
        s50 = stk + " 가격 추이 어때?"
        s51 = stk + " 가격 추이 어떻게 돼?"
        s52 = stk + " 가격 추이 궁금해"
        s53 = stk + " 가격 추이 보고싶어"
        
        question = question + [s1, s2, s3, s4, s5, s6, s7, s8, s9, s10, s11, s12, s13, s14, s15, s16, s17, s18, s19, s20, s21, s22, s23, s24, s25, s26, s27, s28, s29, s30, s31, s32, s33, s34, s35, s36, s37, s38, s39, s40, s41, s42, s43, s44, s45, s46, s47, s48, s49, s50, s51, s52, s53]
    return question

stk_price_questions = generate_stock_price_question(stk_list)

# %% [markdown]
# ### (종목명 제외) 질문에 대한 형태소 저장

# %%
price_question = generate_stock_price_question(['네이버'])
price_question
# Out:
# ['네이버 얼마야?',
#  '네이버 요즘 얼마야?',
#  '네이버 가격',
#  '네이버 시가',
#  '네이버 종가',
#  '네이버 고가',
#  '네이버 저가',
#  '네이버 변화율',
#  '네이버 가격이 어떻게 돼?',
#  '네이버 고가가 어떻게 돼?',
#  '네이버 고가 얼마야?',
#  '네이버 종가 얼마냐',
#  '네이버 고가 보여줘',
#  '네이버 저가 알려줘',
#  '네이버 고가 말해',
#  '네이버 시가가 어떻게 돼?',
#  '네이버 시가 얼마야?',
#  '네이버 시가 얼마냐',
#  '네이버 종가 보여줘',
#  '네이버 저가 알려줘',
#  '네이버 시가 말해',
#  '네이버 변화율은?',
#  '네이버 변화율 몇이야?',
#  '네이버 변화율이 몇이야?',
#  '네이버 변화율 얼마야?',
#  '네이버 변화율 궁금해',
#  '네이버 변화율이 궁금해?',
#  '네이버 그래프',
#  '네이버 그래프 보여줘',
#  '네이버 그래프 띄워줘',
#  '네이버 그래프 띄워',
#  '네이버 그래프 줘',
#  '네이버 그래프 어때?',
#  '네이버 그래프 어떻게 돼?',
#  '네이버 그래프 궁금해',
#  '네이버 그래프 보고싶어',
#  '네이버 차트',
#  '네이버 차트 보여줘',
#  '네이버 차트 띄워줘',
#  '네이버 차트 띄워',
#  '네이버 차트 줘',
#  '네이버 차트 어때?',
#  '네이버 차트 어떻게 돼?',
#  '네이버 차트 궁금해',
#  '네이버 차트 보고싶어',
#  '네이버 가격 추이',
#  '네이버 가격 추이 보여줘',
#  '네이버 가격 추이 띄워줘',
#  '네이버 가격 추이 띄워',
#  '네이버 가격 추이 어때?',
#  '네이버 가격 추이 어떻게 돼?',
#  '네이버 가격 추이 궁금해',
#  '네이버 가격 추이 보고싶어']

# %%
tokenized_question = [mecab.morphs(question) for question in price_question]
tokenized_question
# Out:
# [['네이버', '얼마', '야', '?'],
#  ['네이버', '요즘', '얼마', '야', '?'],
#  ['네이버', '가격'],
#  ['네이버', '시가'],
#  ['네이버', '종가'],
#  ['네이버', '고가'],
#  ['네이버', '저', '가'],
#  ['네이버', '변화', '율'],
#  ['네이버', '가격', '이', '어떻게', '돼', '?'],
#  ['네이버', '고가', '가', '어떻게', '돼', '?'],
#  ['네이버', '고가', '얼마', '야', '?'],
#  ['네이버', '종가', '얼마', '냐'],
#  ['네이버', '고가', '보여줘'],
#  ['네이버', '저', '가', '알려줘'],
#  ['네이버', '고가', '말', '해'],
#  ['네이버', '시가', '가', '어떻게', '돼', '?'],
#  ['네이버', '시가', '얼마', '야', '?'],
#  ['네이버', '시가', '얼마', '냐'],
#  ['네이버', '종가', '보여줘'],
#  ['네이버', '저', '가', '알려줘'],
#  ['네이버', '시가', '말', '해'],
#  ['네이버', '변화', '율', '은', '?'],
#  ['네이버', '변화', '율', '몇', '이', '야', '?'],
#  ['네이버', '변화', '율', '이', '몇', '이', '야', '?'],
#  ['네이버', '변화', '율', '얼마', '야', '?'],
#  ['네이버', '변화', '율', '궁금', '해'],
#  ['네이버', '변화', '율', '이', '궁금', '해', '?'],
#  ['네이버', '그래프'],
#  ['네이버', '그래프', '보여줘'],
#  ['네이버', '그래프', '띄워줘'],
#  ['네이버', '그래프', '띄워'],
#  ['네이버', '그래프', '줘'],
#  ['네이버', '그래프', '어때', '?'],
#  ['네이버', '그래프', '어떻게', '돼', '?'],
#  ['네이버', '그래프', '궁금', '해'],
#  ['네이버', '그래프', '보', '고', '싶', '어'],
#  ['네이버', '차트'],
#  ['네이버', '차트', '보여줘'],
#  ['네이버', '차트', '띄워줘'],
#  ['네이버', '차트', '띄워'],
#  ['네이버', '차트', '줘'],
#  ['네이버', '차트', '어때', '?'],
#  ['네이버', '차트', '어떻게', '돼', '?'],
#  ['네이버', '차트', '궁금', '해'],
#  ['네이버', '차트', '보', '고', '싶', '어'],
#  ['네이버', '가격', '추이'],
#  ['네이버', '가격', '추이', '보여줘'],
#  ['네이버', '가격', '추이', '띄워줘'],
#  ['네이버', '가격', '추이', '띄워'],
#  ['네이버', '가격', '추이', '어때', '?'],
#  ['네이버', '가격', '추이', '어떻게', '돼', '?'],
#  ['네이버', '가격', '추이', '궁금', '해'],
#  ['네이버', '가격', '추이', '보', '고', '싶', '어']]

# %%
stk_price_not_stock_name_list = []
for i in tokenized_question:
    for word in i:
        if word != '네이버':
            stk_price_not_stock_name_list.append(word)
stk_price_not_stock_name_list[:20]
# Out:
# ['얼마',
#  '야',
#  '?',
#  '요즘',
#  '얼마',
#  '야',
#  '?',
#  '가격',
#  '시가',
#  '종가',
#  '고가',
#  '저',
#  '가',
#  '변화',
#  '율',
#  '가격',
#  '이',
#  '어떻게',
#  '돼',
#  '?']

# %%
price_df = pd.DataFrame(zip(stk_price_questions, ['가격']*len(stk_price_questions)), columns = ['question', 'intent'])
price_df
# Out:
#                question intent
# 0           AJ네트웍스 얼마야?     가격
# 1        AJ네트웍스 요즘 얼마야?     가격
# 2             AJ네트웍스 가격     가격
# 3             AJ네트웍스 시가     가격
# 4             AJ네트웍스 종가     가격
# ...                 ...    ...
# 131700      힘스 가격 추이 띄워     가격
# 131701     힘스 가격 추이 어때?     가격
# 131702  힘스 가격 추이 어떻게 돼?     가격
# 131703     힘스 가격 추이 궁금해     가격
# 131704    힘스 가격 추이 보고싶어     가격
#
# [131705 rows x 2 columns]

# %% [markdown]
# ## 키워드 데이터 (keyword_df)

# %% [markdown]
# ### 주식 종목 keyword 데이터 생성
# - 네이버 주식 테마 페이지에서 주식 종목 crawling
# - https://finance.naver.com/sise/theme.naver?&page={0}

# %%
import requests
import tqdm
import re
from random import sample

# %%
def delete_char(text):
    new_text = re.sub(r"[^a-zA-Z0-9ㄱ-ㅎㅏ-ㅣ가-힣 ]","", text)
    return new_text

def create_keyword_list(x):
    lst = []
    for i in x:
        lst += i
    return lst

def get_keywords(url, page):
    url = url.format(page)
    table = pd.read_html(url, encoding = "cp949")
    table = table[0].dropna().iloc[:,0]
    keywords = table.apply(lambda x: keyword_preprocess(x))
    keyword_sublist = create_keyword_list(keywords)
    
    return keyword_sublist


def split_by_space(lst):
    key_list = lst.copy()
    keyword_split_space = list()
    keyword_morphs = list()
    
    for word in key_list:
        keyword_split_space.extend(word.split())
        keyword_morphs += mecab.morphs(word)
        
    return keyword_split_space, keyword_morphs

# %%
url = "https://finance.naver.com/sise/theme.naver?&page={0}"

keyword_list = []
for page in range(1,8):
    keyword_sublist = get_keywords(url, page)
    keyword_list += keyword_sublist


stock_df_industry_keyword = stock_df["industry"].to_list().copy()




keyword_list += stock_df_industry_keyword
keyword_list = list(set(keyword_list))
tmp_keyword = pd.Series(keyword_list.copy()).apply(lambda x : delete_char(x))
tmp_keyword = tmp_keyword.replace("", np.nan)
tmp_keyword = tmp_keyword.dropna()
keyword_list = list(tmp_keyword)
keyword_list.remove("저가")
keyword_list.remove('관련주')



keyword_split_space, keyword_morphs = split_by_space(keyword_list)
keyword_morphs += keyword_split_space
keyword_list = list(set(keyword_morphs))
keyword_series = pd.Series(keyword_list)
keyword_list = list(keyword_series[~(keyword_series.apply(lambda x: len(x)) <= 1)])

sample(keyword_list, 20)
# Out:
# ['방송',
#  '엔젤산업',
#  '사회',
#  '면세점',
#  'LCD장비',
#  '바이오',
#  '2022',
#  '코로나',
#  '블록체인',
#  '창고업',
#  '오락',
#  '증강현실',
#  '가스관사업',
#  '풍력에너지',
#  '3D',
#  '밥솥',
#  '운송장',
#  '유통',
#  '지수',
#  '수도권']

# %% [markdown]
# ### keyword 질문 생성 함수 (training 용도)

# %%
def generate_keyword_question(keyword_list):
    question = []
    for keyword in keyword_list:
        s1 = keyword + " 관련주"
        s2 = keyword + " 관련주 알려줘"
        s3 = keyword + " 관련주 보여줘"
        s4 = keyword + " 관련주 뭐 있어?"
        s5 = keyword + " 관련주 모 있어?"
        s6 = keyword + "랑 관련된 주"
        s7 = keyword + "랑 관련되 주 알려줘"
        s8 = keyword + "랑 관련된 주 보여줘"
        s9 = keyword + "랑 관련된 주 뭐 있어?"
        s10 = keyword + "랑 관련된 주 모 있어?"
        s11 = keyword + "랑 관련된 주식"
        s12 = keyword + "랑 관련된 주식 알려줘"
        s13 = keyword + "랑 관련된 주식 보여줘"
        s14 = keyword + "랑 관련된 주식 뭐 있어?"
        s15 = keyword + "랑 관련된 주식 모 있어?"
        s16 = keyword + " 관련주 검색"
        s17 = keyword + " 연관주"
        s18 = keyword + " 연관주 알려줘"
        s19 = keyword + " 연관주 보여줘"
        s20 = keyword + " 연관주 뭐 있어?"
        s21 = keyword + " 연관주 모 있어?"
        s22 = keyword + "랑 연관된 주"
        s23 = keyword + "랑 연관된 주 알려줘"
        s24 = keyword + "랑 연관된 주 보여줘"
        s25 = keyword + "랑 연관된 주 뭐 있어?"
        s26 = keyword + "랑 연관된 주 모 있어?"
        s27 = keyword + "랑 연관된 주식"
        s28 = keyword + "랑 연관되 주식 알려줘"
        s29 = keyword + "랑 연관된 주식 보여줘"
        s30 = keyword + "랑 연관된 주식 뭐 있어?"
        s31 = keyword + "랑 연관된 주식 모 있어?"
        s32 = keyword + " 연관주 검색"
        
        question = question + [s1,s2,s3,s4,s5,s6,s7,s8,s9,s10,s11,s12,s13,s14,s15,s16,s17,s18,s19,s20,s21,s22,
                               s23,s24,s25,s26,s27,s28,s29,s30,s31,s32]
        
    return question

keyword_questions = generate_keyword_question(keyword_list)

# %%
test_keyword_questions = generate_keyword_question(['가상현실'])

tokenized_question = [mecab.morphs(question) for question in test_keyword_questions]
tokenized_question
# Out:
# [['가상현실', '관련주'],
#  ['가상현실', '관련주', '알려줘'],
#  ['가상현실', '관련주', '보여줘'],
#  ['가상현실', '관련주', '뭐', '있', '어', '?'],
#  ['가상현실', '관련주', '모', '있', '어', '?'],
#  ['가상현실', '랑', '관련', '된', '주'],
#  ['가상현실', '랑', '관련', '되', '주', '알려줘'],
#  ['가상현실', '랑', '관련', '된', '주', '보여줘'],
#  ['가상현실', '랑', '관련', '된', '주', '뭐', '있', '어', '?'],
#  ['가상현실', '랑', '관련', '된', '주', '모', '있', '어', '?'],
#  ['가상현실', '랑', '관련', '된', '주식'],
#  ['가상현실', '랑', '관련', '된', '주식', '알려줘'],
#  ['가상현실', '랑', '관련', '된', '주식', '보여줘'],
#  ['가상현실', '랑', '관련', '된', '주식', '뭐', '있', '어', '?'],
#  ['가상현실', '랑', '관련', '된', '주식', '모', '있', '어', '?'],
#  ['가상현실', '관련주', '검색'],
#  ['가상현실', '연관', '주'],
#  ['가상현실', '연관', '주', '알려줘'],
#  ['가상현실', '연관', '주', '보여줘'],
#  ['가상현실', '연관', '주', '뭐', '있', '어', '?'],
#  ['가상현실', '연관', '주', '모', '있', '어', '?'],
#  ['가상현실', '랑', '연관', '된', '주'],
#  ['가상현실', '랑', '연관', '된', '주', '알려줘'],
#  ['가상현실', '랑', '연관', '된', '주', '보여줘'],
#  ['가상현실', '랑', '연관', '된', '주', '뭐', '있', '어', '?'],
#  ['가상현실', '랑', '연관', '된', '주', '모', '있', '어', '?'],
#  ['가상현실', '랑', '연관', '된', '주식'],
#  ['가상현실', '랑', '연관', '되', '주식', '알려줘'],
#  ['가상현실', '랑', '연관', '된', '주식', '보여줘'],
#  ['가상현실', '랑', '연관', '된', '주식', '뭐', '있', '어', '?'],
#  ['가상현실', '랑', '연관', '된', '주식', '모', '있', '어', '?'],
#  ['가상현실', '연관', '주', '검색']]

# %% [markdown]
# ### (종목명 제외) 질문에 대한 형태소 저장

# %%
not_keyword_list = []
for i in tokenized_question:
    for word in i:
        if word != "가상현실":
            not_keyword_list.append(word)

# %%
keyword_df = pd.DataFrame(zip(keyword_questions, ["키워드"] * len(keyword_questions)), columns= ["question","intent"])
keyword_df.sample(20)
# Out:
#                   question intent
# 12022       케이블랑 연관된 주 알려줘    키워드
# 10583        통신랑 연관된 주 보여줘    키워드
# 3072               PCB 관련주    키워드
# 13552              야놀자 연관주    키워드
# 12203    음식료업종랑 관련된 주식 알려줘    키워드
# 3638       스마트홈랑 연관된 주 알려줘    키워드
# 2093    비철금속랑 관련된 주식 뭐 있어?    키워드
# 12783            출판 관련주 검색    키워드
# 10050         크래프톤 관련주 보여줘    키워드
# 5178            낸드랑 연관된 주식    키워드
# 15131       광고랑 연관되 주식 알려줘    키워드
# 8790        CAR랑 연관된 주 알려줘    키워드
# 8941      생명랑 관련된 주식 뭐 있어?    키워드
# 12042          월드컵랑 관련된 주식    키워드
# 6477    인공지능랑 관련된 주식 뭐 있어?    키워드
# 4201   의료정밀기기랑 관련된 주 모 있어?    키워드
# 3535           리모델링 관련주 검색    키워드
# 13057         원격진료 관련주 알려줘    키워드
# 10811     아프리카랑 연관되 주식 알려줘    키워드
# 8415            부품주 연관주 검색    키워드

# %% [markdown]
# ## 사업개요 데이터 (outline_df)

# %% [markdown]
# ### 사업개요 질문 생성 함수 (training 용도)

# %%
def generate_outline_question(stock_names):
    question = []
    
    for stk in stock_names: 
        s1 = stk + " 사업 개요"
        s2 = stk + " 사업 개요 요약"
        s3 = stk + " 사업 개요 요약해봐"
        s4 = stk + " 사업 개요 요약해바"
        s5 = stk + " 사업 개요 요약해"
        s6 = stk + " 사업 개요 요약해줘"
        s7 = stk + " 사업 개요 제공해"
        s8 = stk + " 사업 개요 제공해줘"
        s9 = stk + " 사업 개요 보여줘"
        s10 = stk + " 사업 개요 볼래"
        s11 = stk + " 사업 개요 알려줘"
        s12 = stk + " 사업 개요 궁금해"
        s13 = stk + " 사업 개요가 궁금해"
        s14 = stk + " 사업 개요가 어떻게 돼?"
        s15 = stk + " 시가총액"
        s16 = stk + " 시가총액 보여줘"
        s17 = stk + " 시가총액 볼래"
        s18 = stk + " 시가총액 알려줘"
        s19 = stk + " 시가총액 궁금해"
        s20 = stk + " 시가총액이 궁금해"
        s21 = stk + " 시가총액이 어떻게 돼?"
        s22 = stk + " 요약"
        
        question = question + [s1,s2,s3,s4,s5,s6,s7,s8,s9,s10,s11,s12,s13,s14,s15,s16,s17,s18,s19,s20,s21,s22]
        
    return question

outline_questions = generate_outline_question(stk_list)

# %% [markdown]
# ### (종목명 제외) 질문에 대한 형태소 저장

# %%
test_outline_question = generate_outline_question(["네이버"])

tokenized_question = [mecab.morphs(question) for question in test_outline_question]
tokenized_question
# Out:
# [['네이버', '사업', '개요'],
#  ['네이버', '사업', '개요', '요약'],
#  ['네이버', '사업', '개요', '요약', '해', '봐'],
#  ['네이버', '사업', '개요', '요약', '해', '바'],
#  ['네이버', '사업', '개요', '요약', '해'],
#  ['네이버', '사업', '개요', '요약', '해', '줘'],
#  ['네이버', '사업', '개요', '제공', '해'],
#  ['네이버', '사업', '개요', '제공', '해', '줘'],
#  ['네이버', '사업', '개요', '보여줘'],
#  ['네이버', '사업', '개요', '볼래'],
#  ['네이버', '사업', '개요', '알려줘'],
#  ['네이버', '사업', '개요', '궁금', '해'],
#  ['네이버', '사업', '개요', '가', '궁금', '해'],
#  ['네이버', '사업', '개요', '가', '어떻게', '돼', '?'],
#  ['네이버', '시가총액'],
#  ['네이버', '시가총액', '보여줘'],
#  ['네이버', '시가총액', '볼래'],
#  ['네이버', '시가총액', '알려줘'],
#  ['네이버', '시가총액', '궁금', '해'],
#  ['네이버', '시가총액', '이', '궁금', '해'],
#  ['네이버', '시가총액', '이', '어떻게', '돼', '?'],
#  ['네이버', '요약']]

# %%
outline_not_stockname_list = []
for i in tokenized_question:
    for word in i:
        if word != "네이버":
            outline_not_stockname_list.append(word)

# %%
outline_df = pd.DataFrame(zip(outline_questions, ["사업개요"] * len(outline_questions)), columns = ["question", "intent"])
outline_df.sample(20)
# Out:
#                      question intent
# 38445    에이치엠씨제4호스팩 사업 개요 궁금해   사업개요
# 16561           태원물산 시가총액 알려줘   사업개요
# 35548          아비코전자 시가총액 궁금해   사업개요
# 49535     태웅로직스 사업 개요가 어떻게 돼?   사업개요
# 18535          한신기계 사업 개요 궁금해   사업개요
# 52182  하나금융14호스팩 시가총액이 어떻게 돼?   사업개요
# 30563          부스타 사업 개요 요약해줘   사업개요
# 12590     엔에이치스팩19호 사업 개요 제공해   사업개요
# 7680          롯데지주 사업 개요 요약해봐   사업개요
# 27645      디티앤씨 사업 개요가 어떻게 돼?   사업개요
# 46593          지아이텍 시가총액이 궁금해   사업개요
# 32293         서울반도체 시가총액이 궁금해   사업개요
# 16493          태양금속우 시가총액 보여줘   사업개요
# 12528       에이플러스에셋 사업 개요 알려줘   사업개요
# 30279        박셀바이오 사업 개요 제공해줘   사업개요
# 33817           스맥 사업 개요 요약해바   사업개요
# 36799          알톤스포츠 시가총액 보여줘   사업개요
# 32254      서울바이오시스 사업 개요 요약해봐   사업개요
# 44949         인화정공 사업 개요 요약해바   사업개요
# 16151        쿠쿠홈시스 사업 개요 요약해바   사업개요

# %% [markdown]
# ## 데이터 concat

# %%
# Data Concatenate
print('similarity_df:', similarity_df.shape)
print('price_df:', price_df.shape)
print('keyword_df:', keyword_df.shape)
print('outline_df:', outline_df.shape)

final_df = pd.concat([similarity_df, price_df, keyword_df, outline_df])
print('final_df: {}'.format(final_df.shape))
final_df.sample(20)
# Out:
# similarity_df: (64610, 2)
# price_df: (131705, 2)
# keyword_df: (15648, 2)
# outline_df: (54670, 2)
# final_df: (266633, 2)
#                   question intent
# 127797         한국캐피탈 고가 말해     가격
# 56160       골프존 그래프 어떻게 돼?     가격
# 24572        샘표 그래프 어떻게 돼?     가격
# 34624   명성티엔에스와 비슷한 주식 보여줘   유사기업
# 62553   한국전자인증랑 비슷한 주식 모야?   유사기업
# 7108         두산 사업 개요 요약해봐   사업개요
# 55262    지오엘리먼트랑 비슷한 항목 모야   유사기업
# 7355        디아이 사업 개요 제공해줘   사업개요
# 23453     현대차증권의 유사 종목 보여줘   유사기업
# 23135              삼양사 그래프     가격
# 8230         5G랑 관련되 주 알려줘    키워드
# 72949          박셀바이오 변화율은?     가격
# 48804     와이즈버즈의 유사 종목 알려줘   유사기업
# 110974           제테마 가격 추이     가격
# 49498        휴비스 가격 추이 어때?     가격
# 23354        광림 사업 개요가 궁금해   사업개요
# 63493    데이타솔루션 가격 추이 보고싶어     가격
# 119387        테고사이언스 그래프 줘     가격
# 19838           팜스코의 유사 종목   유사기업
# 72256         바이오니아 시가 얼마냐     가격

# %%
from sklearn.utils import shuffle
final_df = shuffle(final_df).reset_index(drop = True)
final_df
# Out:
#                        question intent
# 0               포시에스 고가가 어떻게 돼?     가격
# 1                   현대무벡스 고가 말해     가격
# 2       교보10호스팩랑 비슷한 항목은 뭐가 있어?   유사기업
# 3                  쌍용C&E 저가 알려줘     가격
# 4                     에스앤에스텍 요약   사업개요
# ...                         ...    ...
# 266628          케이엠제약 가격 추이 어때?     가격
# 266629           와이제이엠게임즈 변화율은?     가격
# 266630        인지컨트롤스 사업 개요 제공해줘   사업개요
# 266631              지에스이 저가 알려줘     가격
# 266632           엘컴텍와 비슷한 주식 열람   유사기업
#
# [266633 rows x 2 columns]

# %%
final_df.to_csv("./data/intent_df.csv", index = False)

# %%
pd.read_csv("./data/intent_df.csv")
# Out:
#                        question intent
# 0               포시에스 고가가 어떻게 돼?     가격
# 1                   현대무벡스 고가 말해     가격
# 2       교보10호스팩랑 비슷한 항목은 뭐가 있어?   유사기업
# 3                  쌍용C&E 저가 알려줘     가격
# 4                     에스앤에스텍 요약   사업개요
# ...                         ...    ...
# 266628          케이엠제약 가격 추이 어때?     가격
# 266629           와이제이엠게임즈 변화율은?     가격
# 266630        인지컨트롤스 사업 개요 제공해줘   사업개요
# 266631              지에스이 저가 알려줘     가격
# 266632           엘컴텍와 비슷한 주식 열람   유사기업
#
# [266633 rows x 2 columns]

# %% [markdown]
# ## Data preprocessing

# %% [markdown]
# ### Data Label 생성

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.preprocessing.sequence import pad_sequences
from sklearn.model_selection import train_test_split

# %%
ls ./data
# Out:
# dart_data_path.txt  intent_data.csv     stock_names.csv

# %%
final_df = pd.read_csv('./data/intent_data.csv')
final_df.head()
# Out:
#          question intent
# 0  인포마크 변화율이 궁금해?     가격
# 1   경방 사업 개요 제공해줘   사업개요
# 2    풍산 변화율이 궁금해?     가격
# 3      메신저 관련주 검색    키워드
# 4      엠벤처투자 시가총액   사업개요

# %%
final_df.shape
# Out:
# (204351, 2)

# %%
idx_encode = LabelEncoder()
idx_encode.fit(final_df['intent'].to_list())
label_data = idx_encode.transform(final_df['intent'].to_list())
label_data
# Out:
# array([0, 1, 0, ..., 2, 3, 1])

# %%
idx_encode.classes_
# Out:
# array(['가격', '사업개요', '유사기업', '키워드'], dtype='<U4')

# %%
label_idx = dict(zip(list(idx_encode.classes_), idx_encode.transform(list(idx_encode.classes_))))

idx_label = {}
for key, value in label_idx.items():
    idx_label[value] = key
intent_label_size = len(idx_label)
idx_label, intent_label_size
# Out:
# ({0: '가격', 1: '사업개요', 2: '유사기업', 3: '키워드'}, 4)

# %% [markdown]
# ### question data tokenizing

# %%
data_x = [mecab.morphs(question) for question in final_df['question']]
data_x
# Out:
# [['인포마크', '변화', '율', '이', '궁금', '해', '?'],
#  ['경방', '사업', '개요', '제공', '해', '줘'],
#  ['풍산', '변화', '율', '이', '궁금', '해', '?'],
#  ['메신저', '관련주', '검색'],
#  ['엠벤처투자', '시가총액'],
#  ['BNK금융지주', '와', '비슷', '한', '항목', '보여줘'],
#  ['DB손해보험', '와', '비슷', '한', '주식', '알려줘'],
#  ['SV인베스트먼트', '종가'],
#  ['멀티캠퍼스', '요즘', '얼마', '야', '?'],
#  ['지노믹트리', '저', '가', '알려줘'],
#  ['메카로', '가격', '이', '어떻게', '돼', '?'],
#  ['아이앤씨', '랑', '비슷', '한', '항목', '모야'],
#  ['에이디칩스', '랑', '비슷', '한', '항목', '이', '모', '야', '?'],
#  ['대신증권2우B', '고가', '얼마', '야', '?'],
#  ['엠게임', '종가', '보여줘'],
#  ['AJ네트웍스', '랑', '비슷', '한', '주식', '은', '뭐', '가', '있', '어', '?'],
#  ['아이진', '와', '비슷', '한', '주식', '열람'],
#  ['지란지교시큐리티', '사업', '개요', '요약', '해', '바'],
#  ['마이더스AI', '종가', '얼마', '냐'],
#  ['CJ대한통운', '요약'],
#  ['지란지교시큐리티', '변화', '율'],
#  ['브리지텍', '고가', '얼마', '야', '?'],
#  ['샘코', '시가총액', '보여줘'],
#  ['이상네트웍스', '사업', '개요', '요약'],
#  ['이더블유케이', '시가총액', '볼래'],
#  ['계양전기', '의', '유사', '종목', '은', '모', '야', '?'],
#  ['KT&G', '시가총액', '알려줘'],
#  ['현대바이오랜드', '와', '비슷', '한', '주식', '알려줘'],
#  ['빅텍', '의', '유사', '종목', '열람'],
#  ['제낙스', '변화', '율', '이', '몇', '이', '야', '?'],
#  ['신흥', '변화', '율', '은', '?'],
#  ['유성티엔에스', '고가'],
#  ['캠시스', '고가', '가', '어떻게', '돼', '?'],
#  ['젬백스지오', '사업', '개요', '가', '어떻게', '돼', '?'],
#  ['제일바이오', '고가'],
#  ['지역난방공사', '변화', '율', '몇', '이', '야', '?'],
#  ['SK', '가격', '이', '어떻게', '돼', '?'],
#  ['대상홀딩스우', '사업', '개요', '보여줘'],
#  ['클래시스', '랑', '비슷', '한', '항목', '이', '모', '야', '?'],
#  ['하나', '마이크', '론', '랑', '비슷', '한', '항목', '모야'],
#  ['제테마', '저', '가', '알려줘'],
#  ['부국철강', '랑', '비슷', '한', '주식', '이', '모', '야', '?'],
#  ['에치에프알', '시가총액', '알려줘'],
#  ['다우기술', '변화', '율'],
#  ['이지스밸류리츠', '와', '비슷', '한', '항목', '보여줘'],
#  ['한국자산신탁', '의', '유사', '종목', '열람'],
#  ['KCC건설', '시가총액', '보여줘'],
#  ['KPX케미칼', '시가총액', '볼래'],
#  ['성신양회우', '와', '비슷', '한', '항목', '보여줘'],
#  ['한국프랜지', '사업', '개요', '제공', '해', '줘'],
#  ['빅텐츠', '변화', '율', '몇', '이', '야', '?'],
#  ['피에스엠씨', '와', '비슷', '한', '주식', '열람'],
#  ['삼성', 'SDI', '얼마', '야', '?'],
#  ['이지스229호 Class A', '종가'],
#  ['MP그룹', '시가총액', '궁금', '해'],
#  ['남양유업우', '랑', '비슷', '한', '주식', '이', '모야'],
#  ['미래에셋대우우', '시가총액', '알려줘'],
#  ['큐로', '시가총액', '볼래'],
#  ['헝셩그룹', '의', '유사', '종목', '열람'],
#  ['경방', '와', '비슷', '한', '주식', '보여줘'],
#  ['진단', '랑', '관련', '되', '주', '알려줘'],
#  ['신한알파리츠', '고가', '가', '어떻게', '돼', '?'],
#  ['에이스테크', '의', '유사', '종목', '열람'],
#  ['티로보틱스', '변화', '율', '몇', '이', '야', '?'],
#  ['지스마트글로벌', '랑', '비슷', '한', '주식', '이', '모야'],
#  ['LS네트웍스', '변화', '율', '얼마', '야', '?'],
#  ['솔트웍스', '변화', '율', '얼마', '야', '?'],
#  ['한국패러랠', '시가총액', '알려줘'],
#  ['교보10호스팩', '와', '비슷', '한', '항목'],
#  ['동양고속', '종가'],
#  ['이크레더블', '의', '유사', '종목', '열람'],
#  ['겨울', '관련주', '검색'],
#  ['에프엔씨엔터', '와', '비슷', '한', '항목'],
#  ['삼강엠앤티', '의', '유사', '종목', '은', '모', '야', '?'],
#  ['아시아종묘', '변화', '율', '이', '몇', '이', '야', '?'],
#  ['우리들제약', '사업', '개요', '가', '궁금', '해'],
#  ['디에이피', '시가총액'],
#  ['대동스틸', '사업', '개요', '제공', '해'],
#  ['헬릭스미스', '종가', '얼마', '냐'],
#  ['TS인베스트먼트', '랑', '비슷', '한', '주식', '이', '모야'],
#  ['하나대체티마크그랜드부동산1호 F', '와', '비슷', '한', '주식', '알려줘'],
#  ['제노레이', '사업', '개요', '가', '어떻게', '돼', '?'],
#  ['상신전자', '시', '가', '말', '해'],
#  ['자비스', '변화', '율'],
#  ['덕신하우징', '와', '비슷', '한', '주식'],
#  ['디케이앤디', '와', '유사', '종목', '은', '뭐', '가', '있', '어', '?'],
#  ['유유제약2우B', '와', '비슷', '한', '주식', '보여줘'],
#  ['주요종목', '랑', '관련', '된', '주', '모', '있', '어', '?'],
#  ['수혜', '랑', '관련', '된', '주', '뭐', '있', '어', '?'],
#  ['우리', '넷', '변화', '율', '이', '몇', '이', '야', '?'],
#  ['인천도시가스', '사업', '개요', '보여줘'],
#  ['KB 와이즈 스타 부동산 자 2 C-I', '시가총액'],
#  ['KT', '고', '가', '보여줘'],
#  ['엔케이맥스', '시가', '가', '어떻게', '돼', '?'],
#  ['비덴트', '와', '비슷', '한', '항목', '열람'],
#  ['이미지스', '랑', '비슷', '한', '주식', '은', '뭐', '가', '있', '어', '?'],
#  ['센트럴인사이트', '사업', '개요', '알려줘'],
#  ['동운아나텍', '랑', '비슷', '한', '항목', '이', '모', '야', '?'],
#  ['서부T&D', '사업', '개요', '가', '어떻게', '돼', '?'],
#  ['백광산업', '시가총액', '볼래'],
#  ['에스와이', '의', '유사', '종목', '은', '모', '야', '?'],
#  ['디알젬', '종가', '보여줘'],
#  ['NI', 'CE', '와', '비슷', '한', '주식', '보여줘'],
#  ['치아', '랑', '연관', '된', '주식', '뭐', '있', '어', '?'],
#  ['케이프', '고', '가', '보여줘'],
#  ['삼현철강', '의', '유사', '종목', '은', '모야'],
#  ['삼성', 'SDI', '와', '비슷', '한', '항목', '열람'],
#  ['KTis', '시가총액', '궁금', '해'],
#  ['국제약품', '랑', '비슷', '한', '주식', '이', '모야'],
#  ['젬백스지오', '의', '유사', '종목'],
#  ['센트랄모텍', '얼마', '야', '?'],
#  ['씨티씨바이오', '가격', '이', '어떻게', '돼', '?'],
#  ['센트랄모텍', '사업', '개요', '요약', '해', '봐'],
#  ['DGB금융지주', '랑', '비슷', '한', '항목', '모', '야', '?'],
#  ['아이씨케이', '저', '가'],
#  ['원익', 'QnC', '와', '비슷', '한', '주식'],
#  ['백광산업', '얼마', '야', '?'],
#  ['상신전자', '사업', '개요', '제공', '해', '줘'],
#  ['디지아이', '시가총액'],
#  ['하나대체일본부동산1호 P', '랑', '비슷', '한', '항목', '이', '모야'],
#  ['일지테크', '와', '비슷', '한', '주식', '열람'],
#  ['휴마시스', '와', '비슷', '한', '주식', '열람'],
#  ['한국전자인증', '사업', '개요'],
#  ['미투젠', '사업', '개요', '요약'],
#  ['플리토', '변화', '율', '얼마', '야', '?'],
#  ['디자인', '종가', '얼마', '냐'],
#  ['국보', '사업', '개요'],
#  ['컴투스', '사업', '개요', '알려줘'],
#  ['코디엠', '고가', '가', '어떻게', '돼', '?'],
#  ['대신증권우', '시가총액', '이', '궁금', '해'],
#  ['피에스엠씨', '랑', '비슷', '한', '주식', '이', '모', '야', '?'],
#  ['승일', '의', '유사', '종목', '열람'],
#  ['이엔에프테크놀로지', '사업', '개요', '요약', '해', '봐'],
#  ['보해양조', '와', '유사', '종목', '은', '뭐', '가', '있', '어', '?'],
#  ['영원무역홀딩스', '종가', '얼마', '냐'],
#  ['CJ ENM', '랑', '비슷', '한', '주식', '이', '모', '야', '?'],
#  ['웹젠', '랑', '비슷', '한', '주식', '모야'],
#  ['NFT', '관련주', '뭐', '있', '어', '?'],
#  ['유양디앤유', '시가총액', '이', '궁금', '해'],
#  ['시그네틱스', '시', '가', '얼마', '냐'],
#  ['로체시스템즈', '변화', '율'],
#  ['디아이티', '저', '가', '알려줘'],
#  ['비츠로셀', '고가', '얼마', '야', '?'],
#  ['옵트론텍', '사업', '개요'],
#  ['빅솔론', '사업', '개요', '요약', '해'],
#  ['서울리거', '종가'],
#  ['DB하이텍1우', '의', '유사', '종목', '알려줘'],
#  ['차바이오텍', '요약'],
#  ['수프', '로', '사업', '개요', '가', '어떻게', '돼', '?'],
#  ['이씨에스', '와', '비슷', '한', '항목', '알려줘'],
#  ['KNN', '시가총액', '이', '어떻게', '돼', '?'],
#  ['메탈라이프', '와', '유사', '종목', '은', '뭐', '가', '있', '어', '?'],
#  ['유아이디', '랑', '비슷', '한', '주식', '모야'],
#  ['디바이스이엔지', '와', '비슷', '한', '항목', '열람'],
#  ['벨기에코어오피스부동산(C-I)', '시가총액'],
#  ['파라텍', '사업', '개요', '요약', '해', '바'],
#  ['한솔테크닉스', '사업', '개요', '가', '궁금', '해'],
#  ['유안타제6호스팩', '사업', '개요'],
#  ['셀리버리', '변화', '율', '이', '몇', '이', '야', '?'],
#  ['이지바이오', '저', '가', '알려줘'],
#  ['삼지전자', '시가총액', '알려줘'],
#  ['코텍', '사업', '개요', '궁금', '해'],
#  ['리더스 기술투자', '의', '유사', '종목'],
#  ['한국', '내화', '시가총액', '보여줘'],
#  ['프로테옴텍', '시가총액', '이', '궁금', '해'],
#  ['지니언스', '고', '가', '보여줘'],
#  ['대구', '백화점', '와', '비슷', '한', '주식'],
#  ['삼륭물산', '랑', '비슷', '한', '항목', '모야'],
#  ['웰크론한텍', '사업', '개요', '가', '어떻게', '돼', '?'],
#  ['오스코텍', '저', '가', '알려줘'],
#  ['아이에이네트웍스', '시', '가', '말', '해'],
#  ['테라사이언스', '와', '비슷', '한', '항목', '알려줘'],
#  ['테러', '랑', '관련', '된', '주', '모', '있', '어', '?'],
#  ['HDC', '의', '유사', '종목'],
#  ['에이스토리', '사업', '개요', '요약', '해', '바'],
#  ['SKC 솔믹스', '랑', '비슷', '한', '주식', '이', '모', '야', '?'],
#  ['옵티팜', '의', '유사', '종목', '보여줘'],
#  ['진흥기업', '의', '유사', '종목', '알려줘'],
#  ['유비벨록스', '랑', '비슷', '한', '주식', '이', '모야'],
#  ['신영증권', '종가'],
#  ['두올', '랑', '비슷', '한', '항목', '이', '모', '야', '?'],
#  ['녹십자홀딩스', '시', '가', '말', '해'],
#  ['일신바이오', '고가', '말', '해'],
#  ['KNN', '와', '비슷', '한', '주식', '보여줘'],
#  ['KH바텍', '랑', '비슷', '한', '항목', '모야'],
#  ['갤럭시아에스엠', '변화', '율', '몇', '이', '야', '?'],
#  ['시공테크', '시', '가', '말', '해'],
#  ['방송', '랑', '연관', '된', '주식', '보여줘'],
#  ['메디포럼제약', '와', '비슷', '한', '항목', '보여줘'],
#  ['새로닉스', '사업', '개요', '요약', '해', '바'],
#  ['이지스코어부동산126호 C-i', '변화', '율', '이', '몇', '이', '야', '?'],
#  ['제이엘케이', '와', '비슷', '한', '주식', '보여줘'],
#  ['서울리거', '시', '가', '얼마', '야', '?'],
#  ['삼표시멘트', '사업', '개요'],
#  ['알엔투테크놀로지', '와', '유사', '종목', '은', '뭐', '가', '있', '어', '?'],
#  ['유유제약1우', '고가', '얼마', '야', '?'],
#  ['한농화성', '고가', '말', '해'],
#  ['젬백스지오', '사업', '개요', '요약', '해', '봐'],
#  ['코위버', '고가', '얼마', '야', '?'],
#  ['동원시스템즈', '의', '유사', '종목'],
#  ['시공테크', '랑', '비슷', '한', '항목', '은', '뭐', '가', '있', '어', '?'],
#  ['제4이동통신', '랑', '관련', '된', '주식', '뭐', '있', '어', '?'],
#  ['유비쿼스홀딩스', '종가'],
#  ['LG하우시스', '시가총액', '알려줘'],
#  ['루켄테크놀러지스', '의', '유사', '종목'],
#  ['고려산업', '사업', '개요', '요약', '해', '바'],
#  ['포인트엔지니어링', '랑', '비슷', '한', '항목', '은', '뭐', '가', '있', '어', '?'],
#  ['KG모빌리언스', '와', '비슷', '한', '주식', '알려줘'],
#  ['SKC 솔믹스', '시', '가', '얼마', '냐'],
#  ['탄소나노튜브', '랑', '연관', '되', '주식', '알려줘'],
#  ['이노메트리', '요즘', '얼마', '야', '?'],
#  ['미래컴퍼니', '저', '가', '알려줘'],
#  ['NH프라임리츠', '사업', '개요', '보여줘'],
#  ['상보', '사업', '개요', '요약', '해', '줘'],
#  ['효성중공업', '시가총액'],
#  ['신세계푸드', '가격', '이', '어떻게', '돼', '?'],
#  ['KMH하이텍', '시가', '가', '어떻게', '돼', '?'],
#  ['드림어스컴퍼니', '시가'],
#  ['한국', '정보', '통신', '시가총액'],
#  ['동일산업', '와', '비슷', '한', '항목', '알려줘'],
#  ['크라운제과', '변화', '율', '이', '몇', '이', '야', '?'],
#  ['박셀바이오', '와', '비슷', '한', '주식'],
#  ['아스콘', '관련주', '보여줘'],
#  ['이트론', '와', '유사', '종목', '은', '뭐', '가', '있', '어', '?'],
#  ['진양폴리', '변화', '율', '이', '몇', '이', '야', '?'],
#  ['모토닉', '랑', '비슷', '한', '주식', '모', '야', '?'],
#  ['비상', '교육', '고', '가', '말', '해'],
#  ['노루페인트', '시가총액', '이', '어떻게', '돼', '?'],
#  ['삼진', '랑', '비슷', '한', '주식', '은', '뭐', '가', '있', '어', '?'],
#  ['신일전자', '사업', '개요'],
#  ['제이씨현시스템', '종가', '보여줘'],
#  ['세원정공', '요약'],
#  ['윙입푸드', '요약'],
#  ['성광벤드', '변화', '율', '이', '몇', '이', '야', '?'],
#  ['랩지노믹스', '랑', '비슷', '한', '항목', '모', '야', '?'],
#  ['조아제약', '고가', '얼마', '야', '?'],
#  ['모바일어플라이언스', '랑', '비슷', '한', '항목', '모', '야', '?'],
#  ['인디에프', '와', '비슷', '한', '주식'],
#  ['고려산업', '시가총액', '궁금', '해'],
#  ['환인제약', '변화', '율', '얼마', '야', '?'],
#  ['아시아나IDT', '가격', '이', '어떻게', '돼', '?'],
#  ['대성홀딩스', '저', '가', '알려줘'],
#  ['해덕파워웨이', '의', '유사', '종목', '보여줘'],
#  ['면역항암제', '관련주', '모', '있', '어', '?'],
#  ['이건', '산업', '변화', '율', '이', '몇', '이', '야', '?'],
#  ['아프리카TV', '랑', '비슷', '한', '주식', '모', '야', '?'],
#  ['AI', '랑', '관련', '된', '주식', '모', '있', '어', '?'],
#  ['GST', '시가총액', '이', '어떻게', '돼', '?'],
#  ['윈텍', '의', '유사', '종목', '은', '모야'],
#  ['한화투자증권우', '사업', '개요', '제공', '해', '줘'],
#  ['태양', '시가총액', '알려줘'],
#  ['ITX-AI', '시가'],
#  ['키네마스터', '시가총액'],
#  ['원텍', '종가', '보여줘'],
#  ['위지트', '시가총액', '이', '어떻게', '돼', '?'],
#  ['대원전선', '와', '비슷', '한', '항목', '열람'],
#  ['신한제5호스팩', '랑', '비슷', '한', '항목', '은', '뭐', '가', '있', '어', '?'],
#  ['계룡건설', '사업', '개요', '제공', '해', '줘'],
#  ['유안타제5호스팩', '고가'],
#  ['아주', 'IB', '투자', '의', '유사', '종목', '알려줘'],
#  ['구영테크', '저', '가', '알려줘'],
#  ['야놀자', '관련주', '뭐', '있', '어', '?'],
#  ['NEW', '고가'],
#  ['한국전자금융', '시가', '가', '어떻게', '돼', '?'],
#  ['서플러스글로벌', '랑', '비슷', '한', '항목', '이', '모', '야', '?'],
#  ['대주산업', '사업', '개요', '요약', '해', '봐'],
#  ['에스제이켐', '사업', '개요', '요약', '해', '봐'],
#  ['평화산업', '랑', '비슷', '한', '주식', '은', '뭐', '가', '있', '어', '?'],
#  ['에코프로', '의', '유사', '종목', '열람'],
#  ['안랩', '랑', '비슷', '한', '주식', '은', '뭐', '가', '있', '어', '?'],
#  ['아이', '에', '이', '변화', '율', '이', '몇', '이', '야', '?'],
#  ['코텍', '와', '비슷', '한', '주식', '열람'],
#  ['우리', '로', '시가', '가', '어떻게', '돼', '?'],
#  ['하나대체일본부동산1호 C-I', '의', '유사', '종목', '보여줘'],
#  ['키움히어로즈유럽오피스부동산4호 C-I', '변화', '율', '궁금', '해'],
#  ['LCD장비', '연관', '주', '알려줘'],
#  ['서울가스', '와', '비슷', '한', '항목'],
#  ['롯데관광개발', '사업', '개요', '요약', '해', '봐'],
#  ['신영스팩6호', '시', '가', '얼마', '냐'],
#  ['아톤', '의', '유사', '종목', '열람'],
#  ['유신', '의', '유사', '종목', '열람'],
#  ['국영지앤엠', '사업', '개요', '제공', '해', '줘'],
#  ['신영와코루', '시', '가', '얼마', '냐'],
#  ['세종공업', '랑', '비슷', '한', '주식', '이', '모야'],
#  ['대한뉴팜', '사업', '개요', '알려줘'],
#  ['뉴지랩', '사업', '개요', '요약', '해'],
#  ['무림P&P', '의', '유사', '종목', '열람'],
#  ['유아이디', '사업', '개요', '볼래'],
#  ['동양생명', '시', '가', '말', '해'],
#  ['전기자전거', '랑', '연관', '된', '주', '뭐', '있', '어', '?'],
#  ['오리온', '사업', '개요', '요약', '해', '바'],
#  ['한창', '시가'],
#  ['YTN', '종가', '보여줘'],
#  ['한전산업', '랑', '비슷', '한', '항목', '이', '모', '야', '?'],
#  ['키움히어로즈유럽오피스부동산1호 A', '요약'],
#  ['에프앤가이드', '랑', '비슷', '한', '주식', '이', '모', '야', '?'],
#  ['원일특강', '사업', '개요', '가', '어떻게', '돼', '?'],
#  ['일성건설', '사업', '개요', '제공', '해', '줘'],
#  ['라이온켐텍', '사업', '개요', '궁금', '해'],
#  ['라이브파이낸셜', '시', '가', '얼마', '야', '?'],
#  ['핀테크', '랑', '연관', '된', '주식'],
#  ['SK증권우', '시가총액', '보여줘'],
#  ['테스나', '시가총액', '볼래'],
#  ['바이오로그디바이스', '랑', '비슷', '한', '주식', '이', '모', '야', '?'],
#  ['대성홀딩스', '저', '가'],
#  ['KSS해운', '시가총액', '볼래'],
#  ['샘코', '와', '유사', '종목', '은', '뭐', '가', '있', '어', '?'],
#  ['일동홀딩스', '랑', '비슷', '한', '항목', '이', '모', '야', '?'],
#  ['유통', '관련주'],
#  ['성도이엔지', '시가'],
#  ['이디티', '고가'],
#  ['신한소재부품장비A1', '변화', '율', '이', '궁금', '해', '?'],
#  ['하이텍팜', '변화', '율', '궁금', '해'],
#  ['토비스', '랑', '비슷', '한', '항목', '모야'],
#  ['NHN한국사이버결제', '랑', '비슷', '한', '주식', '모', '야', '?'],
#  ['LG상사', '종가', '보여줘'],
#  ['서진오토모티브', '랑', '비슷', '한', '주식', '이', '모', '야', '?'],
#  ['사조산업', '랑', '비슷', '한', '주식', '은', '뭐', '가', '있', '어', '?'],
#  ['피에스케이', '변화', '율', '몇', '이', '야', '?'],
#  ['이엠넷', '저', '가', '알려줘'],
#  ['플레이위드', '시가총액'],
#  ['에이원알폼', '변화', '율'],
#  ['케이엔더블유', '시가총액', '알려줘'],
#  ['앤씨앤', '사업', '개요', '보여줘'],
#  ['나스미디어', '시가총액', '이', '어떻게', '돼', '?'],
#  ['앱클론', '랑', '비슷', '한', '항목', '모', '야', '?'],
#  ['제이앤티씨', '고', '가', '보여줘'],
#  ['남선알미우', '가격', '이', '어떻게', '돼', '?'],
#  ['AP위성', '사업', '개요', '제공', '해'],
#  ['인팩', '랑', '비슷', '한', '항목', '이', '모', '야', '?'],
#  ['비즈니스온', '와', '비슷', '한', '주식', '열람'],
#  ['나노신소재', '시가총액', '알려줘'],
#  ['디지캡', '와', '비슷', '한', '항목', '보여줘'],
#  ['멕아이씨에스', '저', '가', '알려줘'],
#  ['세경하이테크', '시', '가', '얼마', '야', '?'],
#  ['SI', '연관', '주', '모', '있', '어', '?'],
#  ['한샘', '가격', '이', '어떻게', '돼', '?'],
#  ['오리엔트바이오', '변화', '율', '궁금', '해'],
#  ['대한과학', '랑', '비슷', '한', '항목', '모', '야', '?'],
#  ['흥아해운', '와', '비슷', '한', '주식', '열람'],
#  ['제일연마', '시가총액', '볼래'],
#  ['아프리카', 'TV', '종가'],
#  ['피씨디렉트', '와', '유사', '종목', '은', '뭐', '가', '있', '어', '?'],
#  ['엔에이치스팩13호', '시가총액', '이', '어떻게', '돼', '?'],
#  ['선익시스템', '변화', '율', '은', '?'],
#  ['디앤씨미디어', '고', '가', '보여줘'],
#  ['메탈라이프', '시가총액', '이', '궁금', '해'],
#  ['지란지교시큐리티', '의', '유사', '종목', '열람'],
#  ['지엠비코리아', '변화', '율', '궁금', '해'],
#  ['대유플러스', '시가총액', '보여줘'],
#  ['삼화전기', '변화', '율', '이', '몇', '이', '야', '?'],
#  ['하나금융14호스팩', '의', '유사', '종목'],
#  ['동일제강', '의', '유사', '종목'],
#  ['삼양사우', '랑', '비슷', '한', '항목', '모야'],
#  ['하이트진로2우B', '변화', '율', '얼마', '야', '?'],
#  ['한국팩키지', '사업', '개요', '제공', '해'],
#  ['RFID', '랑', '연관', '된', '주'],
#  ['모다이노칩', '시가총액', '볼래'],
#  ['클래시스', '와', '비슷', '한', '항목', '열람'],
#  ['국제약품', '랑', '비슷', '한', '주식', '모야'],
#  ['KT서브마린', '사업', '개요', '요약', '해', '봐'],
#  ['세원', '고가', '얼마', '야', '?'],
#  ['진원생명과학', '와', '유사', '종목', '은', '뭐', '가', '있', '어', '?'],
#  ['라이프사이언스테크놀로지', '변화', '율'],
#  ['DB금융투자', '시가총액', '이', '궁금', '해'],
#  ['우리산업홀딩스', '랑', '비슷', '한', '항목', '이', '모야'],
#  ['풍산홀딩스', '종가', '얼마', '냐'],
#  ['두산솔루스', '와', '비슷', '한', '항목'],
#  ['한진칼우', '종가', '얼마', '냐'],
#  ['KT서브마린', '와', '비슷', '한', '항목', '알려줘'],
#  ['원림', '와', '비슷', '한', '주식', '열람'],
#  ['대성창투', '랑', '비슷', '한', '주식', '은', '뭐', '가', '있', '어', '?'],
#  ['세코닉스', '시가총액', '알려줘'],
#  ['인카금융서비스', '시', '가', '얼마', '야', '?'],
#  ['선바이오', '요즘', '얼마', '야', '?'],
#  ['녹십자엠에스', '변화', '율'],
#  ['이엑스티', '랑', '비슷', '한', '항목', '은', '뭐', '가', '있', '어', '?'],
#  ['경인양행', '랑', '비슷', '한', '주식', '이', '모야'],
#  ['이엔드디', '의', '유사', '종목', '열람'],
#  ['풍국주정', '시가', '가', '어떻게', '돼', '?'],
#  ['디아이티', '시가총액', '이', '어떻게', '돼', '?'],
#  ['동부건설', '변화', '율', '이', '궁금', '해', '?'],
#  ['앱클론', '사업', '개요'],
#  ['크리스에프앤씨', '시가총액', '이', '궁금', '해'],
#  ['에버다임', '가격'],
#  ['AJ네트웍스', '랑', '비슷', '한', '항목', '이', '모야'],
#  ['케이엘넷', '랑', '비슷', '한', '주식', '이', '모야'],
#  ['인스코비', '고', '가', '보여줘'],
#  ['성호전자', '의', '유사', '종목'],
#  ['넥센타이어1우B', '사업', '개요', '알려줘'],
#  ['KIOSK', '랑', '연관', '된', '주식'],
#  ['씨에스윈드', '랑', '비슷', '한', '항목', '모야'],
#  ['보령제약', '랑', '비슷', '한', '주식', '이', '모야'],
#  ['화천기공', '의', '유사', '종목'],
#  ['정다운', '와', '비슷', '한', '항목', '알려줘'],
#  ['데이터스트림즈', '랑', '비슷', '한', '항목', '은', '뭐', '가', '있', '어', '?'],
#  ['에이리츠', '와', '비슷', '한', '주식', '열람'],
#  ['라이프사이언스테크놀로지', '사업', '개요'],
#  ['영림원소프트랩', '요즘', '얼마', '야', '?'],
#  ['비에이치아이', '랑', '비슷', '한', '항목', '은', '뭐', '가', '있', '어', '?'],
#  ['SK증권', '변화', '율', '궁금', '해'],
#  ['롯데칠성', '시가'],
#  ['피에스케이', '시가총액'],
#  ['에이디칩스', '종가', '얼마', '냐'],
#  ['WI', 'SCOM', '변화', '율', '은', '?'],
#  ['KT', '의', '유사', '종목'],
#  ['제주항공', '와', '비슷', '한', '항목', '보여줘'],
#  ['미래테크놀로지', '종가', '보여줘'],
#  ['한라', '사업', '개요', '가', '어떻게', '돼', '?'],
#  ['나우IB', '와', '비슷', '한', '주식'],
#  ['JW홀딩스', '변화', '율', '이', '몇', '이', '야', '?'],
#  ['굿센', '가격', '이', '어떻게', '돼', '?'],
#  ['KTB투자증권', '랑', '비슷', '한', '주식', '이', '모', '야', '?'],
#  ['엘비세미콘', '랑', '비슷', '한', '항목', '모야'],
#  ['무진메디', '사업', '개요', '궁금', '해'],
#  ['티에스이', '사업', '개요', '궁금', '해'],
#  ['드래곤플라이', '사업', '개요', '궁금', '해'],
#  ['골든센츄리', '시가총액', '알려줘'],
#  ['부국증권우', '사업', '개요', '보여줘'],
#  ['하나금융14호스팩', '시가', '가', '어떻게', '돼', '?'],
#  ['아시아종묘', '랑', '비슷', '한', '항목', '이', '모야'],
#  ['육일씨엔에쓰', '사업', '개요', '요약', '해'],
#  ['웅진씽크빅', '와', '비슷', '한', '주식', '열람'],
#  ['올릭스', '와', '비슷', '한', '주식', '알려줘'],
#  ['핸즈코퍼레이션', '사업', '개요', '요약', '해'],
#  ['한일진공', '와', '비슷', '한', '주식', '알려줘'],
#  ['씨큐브', '사업', '개요', '제공', '해'],
#  ['필옵틱스', '시가', '가', '어떻게', '돼', '?'],
#  ['하츠', '사업', '개요', '제공', '해', '줘'],
#  ['지니언스', '가격', '이', '어떻게', '돼', '?'],
#  ['제일연마', '변화', '율', '궁금', '해'],
#  ['한국', '철강', '와', '유사', '종목', '은', '뭐', '가', '있', '어', '?'],
#  ['효성ITX', '랑', '비슷', '한', '항목', '이', '모', '야', '?'],
#  ['대림B&Co', '사업', '개요'],
#  ['한국수출포장', '랑', '비슷', '한', '항목', '은', '뭐', '가', '있', '어', '?'],
#  ['넥스트사이언스', '시가총액', '알려줘'],
#  ['파미셀', '고가', '가', '어떻게', '돼', '?'],
#  ['바이오코아', '와', '비슷', '한', '주식', '보여줘'],
#  ['세미콘라이트', '고가', '말', '해'],
#  ['액트', '로', '저', '가', '알려줘'],
#  ['코오롱우', '변화', '율', '궁금', '해'],
#  ['노랑풍선', '요약'],
#  ['시그넷이브이', '사업', '개요', '보여줘'],
#  ['파인이엠텍', '와', '비슷', '한', '항목', '보여줘'],
#  ['바이오스마트', '의', '유사', '종목', '열람'],
#  ['잉글우드랩', '요즘', '얼마', '야', '?'],
#  ['셀레믹스', '랑', '비슷', '한', '항목', '이', '모', '야', '?'],
#  ['유니온머티리얼', '사업', '개요', '제공', '해', '줘'],
#  ['하나대체일본부동산1호 C-W', '사업', '개요', '요약', '해', '줘'],
#  ['깨끗한나라우', '요즘', '얼마', '야', '?'],
#  ['한송네오텍', '사업', '개요', '요약', '해'],
#  ['성창기업지주', '의', '유사', '종목'],
#  ['윈팩', '의', '유사', '종목', '은', '모야'],
#  ['여름', '연관', '주', '모', '있', '어', '?'],
#  ['NH투자증권', '랑', '비슷', '한', '주식', '이', '모', '야', '?'],
#  ['엔에스컴퍼니', '사업', '개요', '알려줘'],
#  ['광주', '신세계', '종가', '얼마', '냐'],
#  ['태영건설우', '랑', '비슷', '한', '항목', '은', '뭐', '가', '있', '어', '?'],
#  ['웅진', '랑', '비슷', '한', '주식', '이', '모야'],
#  ['HMM', '고', '가', '말', '해'],
#  ['계양전기우', '종가', '얼마', '냐'],
#  ['제닉', '사업', '개요', '가', '궁금', '해'],
#  ['크로바하이텍', '사업', '개요', '요약', '해', '줘'],
#  ['웹스', '시가총액', '이', '어떻게', '돼', '?'],
#  ['디딤', '와', '비슷', '한', '주식', '열람'],
#  ['삼보모터스', '랑', '비슷', '한', '주식', '모야'],
#  ['태양기계', '와', '비슷', '한', '주식'],
#  ['디케이락', '시가총액', '알려줘'],
#  ['경창산업', '얼마', '야', '?'],
#  ['라이브파이낸셜', '랑', '비슷', '한', '주식', '이', '모', '야', '?'],
#  ['창해에탄올', '랑', '비슷', '한', '항목', '이', '모야'],
#  ['진양화학', '사업', '개요', '알려줘'],
#  ['동화약품', '요즘', '얼마', '야', '?'],
#  ['KB 와이즈 스타 부동산 자 2 C-F', '요약'],
#  ['액화천연가스', '연관', '주', '뭐', '있', '어', '?'],
#  ['디지털대성', '랑', '비슷', '한', '주식', '모야'],
#  ['큐로컴', '변화', '율', '이', '궁금', '해', '?'],
#  ['선진', '랑', '비슷', '한', '주식', '모야'],
#  ['롯데정밀화학', '사업', '개요', '요약'],
#  ['나인테크', '시가총액', '보여줘'],
#  ['에이비엘바이오', '변화', '율', '몇', '이', '야', '?'],
#  ['부국철강', '의', '유사', '종목'],
#  ['한양증권', '의', '유사', '종목', '은', '모', '야', '?'],
#  ['한글', '과', '컴퓨터', '시가', '가', '어떻게', '돼', '?'],
#  ['씨앗', '변화', '율', '이', '궁금', '해', '?'],
#  ['인산가', '의', '유사', '종목', '은', '모', '야', '?'],
#  ['STX중공업', '변화', '율', '얼마', '야', '?'],
#  ['압타바이오', '랑', '비슷', '한', '항목', '모', '야', '?'],
#  ['대원', '의', '유사', '종목', '은', '모', '야', '?'],
#  ['핸디소프트', '와', '비슷', '한', '항목', '보여줘'],
#  ['우리이앤엘', '고', '가', '보여줘'],
#  ['지트리비앤티', '랑', '비슷', '한', '주식', '모야'],
#  ['한양증권', '고가'],
#  ['컴투스', '변화', '율', '얼마', '야', '?'],
#  ['엑세스바이오', '의', '유사', '종목', '보여줘'],
#  ['포스코케미칼', '사업', '개요', '가', '어떻게', '돼', '?'],
#  ['삼익THK', '랑', '비슷', '한', '주식', '모', '야', '?'],
#  ['코스맥스비티아이', '랑', '비슷', '한', '항목', '은', '뭐', '가', '있', '어', '?'],
#  ['동양피스톤', '고', '가', '보여줘'],
#  ['서원', '사업', '개요', '제공', '해'],
#  ['넥스트', 'BT', '사업', '개요', '가', '어떻게', '돼', '?'],
#  ['유니테스트', '사업', '개요', '요약', '해', '바'],
#  ['팬엔터테인먼트', '사업', '개요', '요약'],
#  ['제일약품', '변화', '율', '이', '몇', '이', '야', '?'],
#  ['제주항공', '랑', '비슷', '한', '항목', '은', '뭐', '가', '있', '어', '?'],
#  ['크라운해태홀딩스우', '랑', '비슷', '한', '항목', '모야'],
#  ['LS전선아시아', '랑', '비슷', '한', '항목', '모', '야', '?'],
#  ['코스맥스', '변화', '율', '은', '?'],
#  ['애경유화', '종가', '얼마', '냐'],
#  ['백산', '사업', '개요', '요약', '해', '줘'],
#  ['팍스넷', '랑', '비슷', '한', '항목', '이', '모야'],
#  ['동운아나텍', '사업', '개요', '볼래'],
#  ['케이씨에스', '변화', '율'],
#  ['영흥', '의', '유사', '종목', '알려줘'],
#  ['SK네트웍스우', '사업', '개요', '요약', '해', '봐'],
#  ['증권', '연관', '주', '모', '있', '어', '?'],
#  ['GRT', '사업', '개요', '요약', '해'],
#  ['금호산업', '가격', '이', '어떻게', '돼', '?'],
#  ['하이스틸', '랑', '비슷', '한', '주식', '모', '야', '?'],
#  ['로보로보', '저', '가'],
#  ['DRB동일', '사업', '개요', '궁금', '해'],
#  ['매일유업', '시가총액', '보여줘'],
#  ['포스코엠텍', '고가', '얼마', '야', '?'],
#  ['동남합성', '고가', '얼마', '야', '?'],
#  ['이지스196호 Class A', '랑', '비슷', '한', '항목', '모야'],
#  ['이지스코어부동산제117호A', '얼마', '야', '?'],
#  ['슈프리마에이치큐', '요약'],
#  ['아모레퍼시픽우', '랑', '비슷', '한', '주식', '이', '모야'],
#  ['디지탈옵틱', '고가', '가', '어떻게', '돼', '?'],
#  ['경동인베스트', '시가총액', '알려줘'],
#  ['나이벡', '시가총액', '볼래'],
#  ['NPC', '와', '비슷', '한', '주식'],
#  ['경남바이오파마', '요즘', '얼마', '야', '?'],
#  ['NH투자증권', '고가', '가', '어떻게', '돼', '?'],
#  ['한솔인티큐브', '사업', '개요'],
#  ['경남제약헬스케어', '와', '비슷', '한', '주식'],
#  ['에이치엘사이언스', '랑', '비슷', '한', '항목', '은', '뭐', '가', '있', '어', '?'],
#  ['제이앤티씨', '사업', '개요', '궁금', '해'],
#  ['한화손해보험', '시가총액', '알려줘'],
#  ['율촌화학', '얼마', '야', '?'],
#  ['CCTV＆DVR', '랑', '관련', '된', '주식'],
#  ['엘이티', '변화', '율', '이', '몇', '이', '야', '?'],
#  ['지스마트글로벌', '사업', '개요', '요약', '해', '줘'],
#  ['피앤이솔루션', '요즘', '얼마', '야', '?'],
#  ['코스메카코리아', '가격'],
#  ['인포바인', '랑', '비슷', '한', '항목', '모', '야', '?'],
#  ['F&F', '와', '비슷', '한', '항목', '열람'],
#  ['음압병실', '연관', '주', '뭐', '있', '어', '?'],
#  ['에쓰씨엔지니어링', '랑', '비슷', '한', '주식', '이', '모', '야', '?'],
#  ['이십일스토어', '얼마', '야', '?'],
#  ['에스에이엠티', '랑', '비슷', '한', '주식', '모', '야', '?'],
#  ['HRS', '의', '유사', '종목', '보여줘'],
#  ['피에스텍', '종가'],
#  ['메디톡스', '변화', '율', '얼마', '야', '?'],
#  ['LG하우시스', '와', '비슷', '한', '주식', '알려줘'],
#  ['애니젠', '사업', '개요', '가', '궁금', '해'],
#  ['이상네트웍스', '시가총액', '보여줘'],
#  ['매일홀딩스', '사업', '개요', '가', '궁금', '해'],
#  ['비료', '랑', '연관', '된', '주', '뭐', '있', '어', '?'],
#  ['예선테크', '랑', '비슷', '한', '주식', '이', '모', '야', '?'],
#  ['HSD엔진', '변화', '율', '이', '몇', '이', '야', '?'],
#  ['손해보험', '랑', '연관', '된', '주', '알려줘'],
#  ['비나텍', '사업', '개요', '요약', '해'],
#  ['하나대체미국LA부동산1호 F', '시', '가', '말', '해'],
#  ['조광피혁', '시가', '가', '어떻게', '돼', '?'],
#  ['선창산업', '랑', '비슷', '한', '주식', '은', '뭐', '가', '있', '어', '?'],
#  ['삼양홀딩스우', '가격'],
#  ['천랩', '와', '비슷', '한', '주식', '알려줘'],
#  ['동양에스텍', '사업', '개요', '볼래'],
#  ['크로바하이텍', '고가', '말', '해'],
#  ['SK이노베이션우', '시가총액', '보여줘'],
#  ['쿠팡', '연관', '주', '보여줘'],
#  ['국보', '와', '비슷', '한', '항목', '알려줘'],
#  ['아미노로직스', '고가', '얼마', '야', '?'],
#  ['태림포장', '요즘', '얼마', '야', '?'],
#  ['디엔에이링크', '요즘', '얼마', '야', '?'],
#  ['THE E&M', '시가총액'],
#  ['크라운해태홀딩스', '변화', '율', '이', '궁금', '해', '?'],
#  ['일진디스플', '사업', '개요', '제공', '해', '줘'],
#  ['보령제약', '사업', '개요', '볼래'],
#  ['멀티캠퍼스', '사업', '개요', '보여줘'],
#  ['삼아제약', '와', '비슷', '한', '주식'],
#  ['사물인터넷', '랑', '관련', '된', '주', '모', '있', '어', '?'],
#  ['SK바이오팜', '와', '비슷', '한', '주식', '열람'],
#  ['위지트', '사업', '개요', '제공', '해', '줘'],
#  ['스포츠행사', '랑', '연관', '된', '주식', '모', '있', '어', '?'],
#  ['아나패스', '와', '비슷', '한', '주식', '알려줘'],
#  ['평화산업', '의', '유사', '종목', '알려줘'],
#  ['큐리언트', '변화', '율', '궁금', '해'],
#  ['메지온', '시가총액'],
#  ['현대그린푸드', '와', '유사', '종목', '은', '뭐', '가', '있', '어', '?'],
#  ['엘오티베큠', '랑', '비슷', '한', '항목', '이', '모', '야', '?'],
#  ['디엔에프', '고가', '말', '해'],
#  ['무림SP', '종가'],
#  ['BNK금융지주', '가격'],
#  ['대봉엘에스', '변화', '율', '이', '몇', '이', '야', '?'],
#  ['KB와이즈스타부동산3A', '고가'],
#  ['레고켐바이오', '와', '유사', '종목', '은', '뭐', '가', '있', '어', '?'],
#  ['한성기업', '의', '유사', '종목', '열람'],
#  ['KG동부제철우', '랑', '비슷', '한', '주식', '모', '야', '?'],
#  ['아시아나IDT', '종가'],
#  ['에이프로', '랑', '비슷', '한', '주식', '모', '야', '?'],
#  ['신영증권우', '와', '비슷', '한', '주식', '알려줘'],
#  ['케이엔더블유', '랑', '비슷', '한', '주식', '모야'],
#  ['렘데시비르', '랑', '관련', '된', '주'],
#  ['GH신소재', '랑', '비슷', '한', '항목', '이', '모', '야', '?'],
#  ['에스엠코어', '저', '가', '알려줘'],
#  ['일진전기', '와', '비슷', '한', '항목', '알려줘'],
#  ['알에프세미', '저', '가'],
#  ['개발', '랑', '관련', '된', '주', '보여줘'],
#  ['빅히트', '의', '유사', '종목', '은', '모', '야', '?'],
#  ['대양금속', '의', '유사', '종목', '보여줘'],
#  ['노루페인트우', '사업', '개요', '요약', '해', '봐'],
#  ['비씨월드제약', '의', '유사', '종목', '은', '모야'],
#  ['동국제약', '사업', '개요', '요약', '해', '바'],
#  ['헝셩그룹', '랑', '비슷', '한', '항목', '은', '뭐', '가', '있', '어', '?'],
#  ['코프라', '시', '가', '말', '해'],
#  ['이즈미디어', '고가', '얼마', '야', '?'],
#  ['버킷스튜디오', '시가', '가', '어떻게', '돼', '?'],
#  ['한송네오텍', '와', '비슷', '한', '주식', '보여줘'],
#  ['한국', '자산', '신탁', '가격', '이', '어떻게', '돼', '?'],
#  ['신라젠', '사업', '개요', '가', '궁금', '해'],
#  ['YG', 'PLUS', '사업', '개요', '궁금', '해'],
#  ['SK네트웍스우', '요즘', '얼마', '야', '?'],
#  ['제이씨현시스템', '의', '유사', '종목'],
#  ['CS홀딩스', '사업', '개요', '볼래'],
#  ['모다이노칩', '의', '유사', '종목', '보여줘'],
#  ['아이엠', '랑', '비슷', '한', '주식', '모', '야', '?'],
#  ['현대에이치씨엔', '종가', '얼마', '냐'],
#  ['영풍', '와', '비슷', '한', '항목', '알려줘'],
#  ['KD', '사업', '개요', '제공', '해'],
#  ['농우바이오', '랑', '비슷', '한', '주식', '모', '야', '?'],
#  ['대창스틸', '변화', '율', '궁금', '해'],
#  ['한라홀딩스', '변화', '율', '은', '?'],
#  ['타이어', '관련주'],
#  ['동양에스텍', '변화', '율', '얼마', '야', '?'],
#  ['에스에프', '에', '이', '사업', '개요', '요약'],
#  ['디스플레이텍', '사업', '개요', '보여줘'],
#  ['두산솔루스1우', '와', '비슷', '한', '주식', '열람'],
#  ['성창기업지주', '가격'],
#  ['크로넥스', '저', '가', '알려줘'],
#  ['화신정공', '시', '가', '얼마', '야', '?'],
#  ['서연이화', '종가', '얼마', '냐'],
#  ['한라', '변화', '율', '궁금', '해'],
#  ['DB금융투자', '사업', '개요', '요약', '해', '바'],
#  ['이지스229호 Class C-I', '의', '유사', '종목', '열람'],
#  ['화성산업', '와', '비슷', '한', '주식', '알려줘'],
#  ['조흥', '사업', '개요', '볼래'],
#  ['에스앤디', '의', '유사', '종목', '알려줘'],
#  ['내츄럴엔도텍', '와', '비슷', '한', '주식', '알려줘'],
#  ['전자결제', '랑', '연관', '된', '주', '뭐', '있', '어', '?'],
#  ['카페24', '변화', '율', '얼마', '야', '?'],
#  ['금호전기', '고가'],
#  ['우진비앤지', '사업', '개요', '볼래'],
#  ['밥솥', '랑', '관련', '된', '주식', '알려줘'],
#  ['대상우', '저', '가', '알려줘'],
#  ['삼화콘덴서', '시가총액', '이', '어떻게', '돼', '?'],
#  ['케이에스피', '고가', '얼마', '야', '?'],
#  ['롯데푸드', '와', '비슷', '한', '항목'],
#  ['오션스톤', '시', '가', '말', '해'],
#  ['선도전기', '고가', '얼마', '야', '?'],
#  ['유니크', '사업', '개요', '요약'],
#  ['네온테크', '와', '비슷', '한', '주식', '열람'],
#  ['아이피몬스터', '와', '비슷', '한', '주식'],
#  ['액션스퀘어', '랑', '비슷', '한', '주식', '이', '모야'],
#  ['엑스큐어', '시가총액', '알려줘'],
#  ['크리스탈지노믹스', '사업', '개요', '요약', '해', '줘'],
#  ['TCC스틸', '가격'],
#  ['한솔테크닉스', '고가'],
#  ['엠아이텍', '사업', '개요', '요약', '해', '바'],
#  ['이지스299호A', '사업', '개요', '요약', '해', '바'],
#  ['포스코강판', '와', '비슷', '한', '주식', '알려줘'],
#  ['CCTV＆DVR', '랑', '관련', '된', '주', '모', '있', '어', '?'],
#  ['오리엔트정공', '의', '유사', '종목', '은', '모', '야', '?'],
#  ['비씨월드제약', '변화', '율', '은', '?'],
#  ['파마리서치바이오', '와', '비슷', '한', '항목'],
#  ['삼', '일', '사업', '개요', '보여줘'],
#  ['LS ELECTRIC', '저', '가', '알려줘'],
#  ['코메론', '랑', '비슷', '한', '항목', '모', '야', '?'],
#  ['한미글로벌', '와', '비슷', '한', '항목', '열람'],
#  ['네오크레마', '사업', '개요', '제공', '해'],
#  ['파커스', '변화', '율', '몇', '이', '야', '?'],
#  ['녹십자셀', '종가', '얼마', '냐'],
#  ['케이피엠테크', '와', '비슷', '한', '주식'],
#  ['모다이노칩', '종가'],
#  ['넥센', '가격', '이', '어떻게', '돼', '?'],
#  ['빛샘전자', '변화', '율', '궁금', '해'],
#  ['휴림로봇', '의', '유사', '종목', '열람'],
#  ['동국제약', '의', '유사', '종목', '은', '모', '야', '?'],
#  ['까뮤이앤씨', '와', '비슷', '한', '주식', '열람'],
#  ['대유플러스', '사업', '개요', '제공', '해', '줘'],
#  ['한국아트라스비엑스', '랑', '비슷', '한', '주식', '이', '모', '야', '?'],
#  ['DB금융스팩7호', '랑', '비슷', '한', '주식', '모', '야', '?'],
#  ['테스', '고가', '말', '해'],
#  ['광진윈텍', '와', '비슷', '한', '주식'],
#  ['AJ네트웍스', '랑', '비슷', '한', '항목', '모', '야', '?'],
#  ['넵튠', '사업', '개요', '보여줘'],
#  ['뉴지랩', '와', '비슷', '한', '주식', '알려줘'],
#  ['대신증권우', '시', '가', '얼마', '야', '?'],
#  ['선광', '사업', '개요', '볼래'],
#  ['케이씨텍', '의', '유사', '종목'],
#  ['대마', '랑', '연관', '되', '주식', '알려줘'],
#  ['LNG', '랑', '연관', '된', '주'],
#  ['하나대체미국LA부동산1호 F', '와', '비슷', '한', '주식', '열람'],
#  ['바이오솔루션', '랑', '비슷', '한', '주식', '은', '뭐', '가', '있', '어', '?'],
#  ['MH에탄올', '와', '비슷', '한', '주식', '보여줘'],
#  ['텔레칩스', '사업', '개요', '요약', '해', '줘'],
#  ['보라티알', '시가총액', '보여줘'],
#  ['락앤락', '가격'],
#  ['TS트릴리온', '랑', '비슷', '한', '항목', '모야'],
#  ['원림', '의', '유사', '종목', '열람'],
#  ['롯데하이마트', '고', '가', '보여줘'],
#  ['NE능률', '랑', '비슷', '한', '주식', '이', '모야'],
#  ['파나진', '고가'],
#  ['일진디스플', '시', '가', '얼마', '냐'],
#  ['네패스', '저', '가', '알려줘'],
#  ['금강공업', '와', '비슷', '한', '주식', '알려줘'],
#  ['볼빅', '와', '비슷', '한', '주식', '열람'],
#  ['신한BNPP서울시지하철9호선4호', '사업', '개요', '가', '궁금', '해'],
#  ['폭스소프트', '사업', '개요', '보여줘'],
#  ['슈프리마', '사업', '개요', '볼래'],
#  ['CJ씨푸드1우', '요즘', '얼마', '야', '?'],
#  ['선창산업', '의', '유사', '종목', '보여줘'],
#  ['현대차3우B', '고', '가', '보여줘'],
#  ['지스마트글로벌', '사업', '개요', '요약', '해'],
#  ['하이제4호스팩', '랑', '비슷', '한', '항목', '모야'],
#  ['체시스', '요즘', '얼마', '야', '?'],
#  ['KG이니시스', '요즘', '얼마', '야', '?'],
#  ['파버나인', '랑', '비슷', '한', '주식', '모야'],
#  ['티피씨글로벌', '와', '비슷', '한', '항목', '열람'],
#  ['광주', '신세계', '와', '비슷', '한', '주식', '보여줘'],
#  ['경동나비엔', '시', '가', '말', '해'],
#  ['피플바이오', '가격'],
#  ['동양물산', '사업', '개요', '알려줘'],
#  ['큐로컴', '가격', '이', '어떻게', '돼', '?'],
#  ['배럴', '의', '유사', '종목', '보여줘'],
#  ['진양폴리', '변화', '율', '궁금', '해'],
#  ['롯데관광개발', '종가', '보여줘'],
#  ['카카오', '저', '가', '알려줘'],
#  ['유유제약', '시가'],
#  ['현대중공업지주', '사업', '개요', '가', '어떻게', '돼', '?'],
#  ['동양', '시가', '가', '어떻게', '돼', '?'],
#  ['릭스솔루션', '랑', '비슷', '한', '항목', '이', '모', '야', '?'],
#  ['바이브컴퍼니', '변화', '율', '몇', '이', '야', '?'],
#  ['오픈베이스', '종가', '얼마', '냐'],
#  ['솔브레인홀딩스', '변화', '율', '이', '궁금', '해', '?'],
#  ['씨큐브', '사업', '개요', '가', '궁금', '해'],
#  ['하나대체일본부동산1호 P', '시가총액', '궁금', '해'],
#  ['엘브이엠씨홀딩스', '사업', '개요'],
#  ['동원F&B', '와', '비슷', '한', '항목', '열람'],
#  ['하나대체미국LA부동산1호 A', '시가'],
#  ['사료', '연관', '주', '알려줘'],
#  ['시스템통합', '연관', '주', '모', '있', '어', '?'],
#  ['시그네틱스', '의', '유사', '종목'],
#  ['이건홀딩스', '얼마', '야', '?'],
#  ['UAM', '연관', '주', '알려줘'],
#  ['이베스트이안스팩1호', '의', '유사', '종목', '알려줘'],
#  ['유비쿼스', '랑', '비슷', '한', '항목', '은', '뭐', '가', '있', '어', '?'],
#  ['폭스소프트', '와', '비슷', '한', '주식', '열람'],
#  ['대신Japan하임03호C-W', '시', '가', '얼마', '야', '?'],
#  ['대원전선', '와', '비슷', '한', '주식', '알려줘'],
#  ['코로나19', '랑', '관련', '되', '주', '알려줘'],
#  ['큐로', '종가'],
#  ['인탑스', '변화', '율', '이', '궁금', '해', '?'],
#  ['카이노스메드', '사업', '개요'],
#  ['켐트로스', '와', '비슷', '한', '항목', '열람'],
#  ['삼성전자', '종가'],
#  ['드림텍', '종가'],
#  ['아스콘', '관련주'],
#  ['포스코강판', '가격', '이', '어떻게', '돼', '?'],
#  ['디와이', '랑', '비슷', '한', '주식', '은', '뭐', '가', '있', '어', '?'],
#  ['파인디앤씨', '변화', '율', '이', '궁금', '해', '?'],
#  ['대덕1우', '와', '비슷', '한', '항목', '알려줘'],
#  ['우림기계', '의', '유사', '종목'],
#  ['항공사', '관련주', '검색'],
#  ['녹십자셀', '사업', '개요', '요약', '해'],
#  ['엔투텍', '사업', '개요', '알려줘'],
#  ['코오롱머티리얼', '시가총액', '궁금', '해'],
#  ['제노포커스', '요약'],
#  ['삼성SDI', '시가총액', '볼래'],
#  ['투비소프트', '시가총액', '궁금', '해'],
#  ['한컴위드', '시가총액', '이', '어떻게', '돼', '?'],
#  ['테스나', '와', '유사', '종목', '은', '뭐', '가', '있', '어', '?'],
#  ['조광피혁', '의', '유사', '종목', '알려줘'],
#  ['아가방컴퍼니', '의', '유사', '종목', '은', '모야'],
#  ['LG디스플레이', '가격', '이', '어떻게', '돼', '?'],
#  ['메디포스트', '요즘', '얼마', '야', '?'],
#  ['방림', '사업', '개요', '보여줘'],
#  ['동서', '고가', '가', '어떻게', '돼', '?'],
#  ['현대유퍼스트부동산30호[파생형] A', '사업', '개요', '요약', '해'],
#  ['파인디지털', '얼마', '야', '?'],
#  ['동방아그로', '와', '비슷', '한', '주식', '알려줘'],
#  ['팜스코', '변화', '율', '이', '궁금', '해', '?'],
#  ['상신이디피', '변화', '율', '궁금', '해'],
#  ['동우팜투테이블', '사업', '개요', '가', '궁금', '해'],
#  ['유투바이오', '변화', '율', '은', '?'],
#  ['마이크로디지탈', '사업', '개요'],
#  ['키움히어로즈유럽오피스부동산3호 C-I', '고가', '얼마', '야', '?'],
#  ['바이넥스', '사업', '개요', '볼래'],
#  ['씨젠', '종가', '보여줘'],
#  ['앱클론', '변화', '율', '궁금', '해'],
#  ['한솔', 'PNS', '사업', '개요', '요약', '해', '봐'],
#  ['SK네트웍스', '변화', '율', '몇', '이', '야', '?'],
#  ['LG하우시스우', '종가'],
#  ['삼진제약', '와', '비슷', '한', '항목', '보여줘'],
#  ['웰크론한텍', '종가', '보여줘'],
#  ['효성', 'ITX', '와', '비슷', '한', '주식', '알려줘'],
#  ['코오롱글로벌', '시가총액', '이', '궁금', '해'],
#  ['유안타증권우', '변화', '율', '몇', '이', '야', '?'],
#  ['압타바이오', '랑', '비슷', '한', '주식', '이', '모야'],
#  ['시너지이노베이션', '시가총액', '알려줘'],
#  ['성창오토텍', '랑', '비슷', '한', '항목', '은', '뭐', '가', '있', '어', '?'],
#  ['남화토건', '의', '유사', '종목', '알려줘'],
#  ['클리오', '고가', '얼마', '야', '?'],
#  ['포메탈', '변화', '율'],
#  ['동성화인텍', '랑', '비슷', '한', '주식', '은', '뭐', '가', '있', '어', '?'],
#  ['큐로홀딩스', '저', '가', '알려줘'],
#  ['이지스229호 Class A', '시가총액', '보여줘'],
#  ['우리이앤엘', '의', '유사', '종목', '은', '모', '야', '?'],
#  ['S&T모티브', '시가총액'],
#  ['테라사이언스', '와', '비슷', '한', '주식', '보여줘'],
#  ['대덕1우', '의', '유사', '종목', '은', '모야'],
#  ['상상인인더스트리', '변화', '율', '이', '몇', '이', '야', '?'],
#  ['메리츠증권', '사업', '개요', '궁금', '해'],
#  ['대성에너지', '와', '비슷', '한', '항목'],
#  ['에스앤에스텍', '사업', '개요', '요약', '해'],
#  ['에이치엘비생명과학', '사업', '개요', '요약', '해'],
#  ['키네마스터', '의', '유사', '종목', '은', '모', '야', '?'],
#  ['모토닉', '저', '가'],
#  ['케이씨', '랑', '비슷', '한', '항목', '이', '모야'],
#  ['영원무역', '의', '유사', '종목'],
#  ['틸론', '랑', '비슷', '한', '항목', '이', '모야'],
#  ['아이엠', '시가', '가', '어떻게', '돼', '?'],
#  ['도쿄오피스1', '저', '가'],
#  ['에이펙스인텍', '저', '가', '알려줘'],
#  ['LED', '랑', '연관', '된', '주', '뭐', '있', '어', '?'],
#  ['바이넥스', '와', '비슷', '한', '항목', '보여줘'],
#  ['한미약품', '랑', '비슷', '한', '주식', '이', '모야'],
#  ['대원제약', '의', '유사', '종목', '보여줘'],
#  ['아모레G', '시가'],
#  ['한솔테크닉스', '변화', '율', '궁금', '해'],
#  ['코아시아', '사업', '개요', '제공', '해', '줘'],
#  ['미원에스씨', '랑', '비슷', '한', '항목', '이', '모야'],
#  ['에브리봇', '변화', '율', '얼마', '야', '?'],
#  ['조이시티', '얼마', '야', '?'],
#  ['아이앤씨', '와', '비슷', '한', '주식', '열람'],
#  ['에스아이리소스', '시가총액', '보여줘'],
#  ['코오롱티슈진', '와', '비슷', '한', '항목', '열람'],
#  ['와이팜', '변화', '율', '은', '?'],
#  ['글로벌에스엠', '사업', '개요'],
#  ['셀바스AI', '와', '비슷', '한', '항목'],
#  ['미원상사', '시', '가', '얼마', '냐'],
#  ['펩트론', '랑', '비슷', '한', '항목', '이', '모', '야', '?'],
#  ['단디바이오', '고', '가', '보여줘'],
#  ['알톤스포츠', '고가', '말', '해'],
#  ['휴스틸', '사업', '개요', '요약', '해', '바'],
#  ['에이치케이', '랑', '비슷', '한', '주식', '이', '모야'],
#  ['원익큐브', '종가', '보여줘'],
#  ['에코플라스틱', '고가', '얼마', '야', '?'],
#  ['IBKS제11호스팩', '랑', '비슷', '한', '항목', '모', '야', '?'],
#  ['신한지주', '변화', '율', '은', '?'],
#  ['동운아나텍', '사업', '개요', '궁금', '해'],
#  ['디젠스', '랑', '비슷', '한', '항목', '이', '모야'],
#  ['현대위아', '시가'],
#  ['바이오인프라생명과학', '사업', '개요', '요약', '해', '바'],
#  ['까스텔바작', '의', '유사', '종목', '알려줘'],
#  ['대동스틸', '의', '유사', '종목', '열람'],
#  ['넥스턴', '랑', '비슷', '한', '주식', '이', '모야'],
#  ['삼영무역', '와', '비슷', '한', '항목'],
#  ['디에이치피코리아', '요즘', '얼마', '야', '?'],
#  ['에스아이리소스', '사업', '개요', '볼래'],
#  ['이지스글로벌281호 Class A', '랑', '비슷', '한', '항목', '이', '모', '야', '?'],
#  ['제룡전기', '사업', '개요', '궁금', '해'],
#  ['린드먼아시아', '사업', '개요', '요약', '해', '줘'],
#  ['레몬', '랑', '비슷', '한', '주식', '이', '모', '야', '?'],
#  ['현대유퍼스트부동산25호 C-i', '와', '비슷', '한', '주식', '열람'],
#  ['우성사료', '의', '유사', '종목'],
#  ['아이엘사이언스', '랑', '비슷', '한', '주식', '이', '모', '야', '?'],
#  ['키움히어로즈유럽오피스부동산4호 A', '변화', '율', '이', '몇', '이', '야', '?'],
#  ['피에스엠씨', '와', '비슷', '한', '항목', '열람'],
#  ['빅솔론', '와', '비슷', '한', '주식', '열람'],
#  ['DB하이텍1우', '사업', '개요', '요약', '해'],
#  ['LPG', '랑', '관련', '된', '주식'],
#  ['현대리바트', '와', '비슷', '한', '주식', '보여줘'],
#  ['에스앤더블류', '고가'],
#  ['바이온', '종가', '보여줘'],
#  ['액토즈소프트', '변화', '율', '이', '궁금', '해', '?'],
#  ['티피씨글로벌', '와', '비슷', '한', '주식'],
#  ['세원셀론텍', '의', '유사', '종목', '은', '모야'],
#  ['백산', '랑', '비슷', '한', '주식', '모', '야', '?'],
#  ['액트', '랑', '비슷', '한', '주식', '모', '야', '?'],
#  ['줌인터넷', '사업', '개요', '알려줘'],
#  ['자동차', '관련주', '뭐', '있', '어', '?'],
#  ['롯데쇼핑', '시', '가', '얼마', '냐'],
#  ['GH신소재', '고가'],
#  ['지어소프트', '시가총액'],
#  ['국순당', '사업', '개요', '요약', '해'],
#  ['에이티넘인베스트', '사업', '개요', '궁금', '해'],
#  ['유나이티드제약', '와', '비슷', '한', '항목', '열람'],
#  ['빅텍', '랑', '비슷', '한', '항목', '이', '모야'],
#  ['낸드', '연관', '주', '검색'],
#  ['기업', '은행', '변화', '율'],
#  ['케이탑리츠', '의', '유사', '종목'],
#  ['명진홀딩스', '종가', '얼마', '냐'],
#  ['S-Oil', '가격'],
#  ['액트', '변화', '율', '이', '궁금', '해', '?'],
#  ['디엠티', '시가총액', '보여줘'],
#  ['액트', '로', '요약'],
#  ['송원산업', '와', '비슷', '한', '주식'],
#  ['질경', '이', '사업', '개요', '가', '궁금', '해'],
#  ['아이즈비전', '의', '유사', '종목', '보여줘'],
#  ['위더스제약', '와', '비슷', '한', '주식', '열람'],
#  ['삼정펄프', '시가총액'],
#  ['테이팩스', '시가', '가', '어떻게', '돼', '?'],
#  ['제이씨케미칼', '사업', '개요', '볼래'],
#  ['셀트리온', '와', '비슷', '한', '주식', '보여줘'],
#  ['인천도시가스', '의', '유사', '종목', '은', '모야'],
#  ['대호에이엘', '랑', '비슷', '한', '주식', '모', '야', '?'],
#  ['에이스토리', '의', '유사', '종목'],
#  ['한국가스공사', '랑', '비슷', '한', '항목', '이', '모야'],
#  ['현대미포조선', '종가'],
#  ['신원종합개발', '의', '유사', '종목'],
#  ['KT', '사업', '개요', '제공', '해', '줘'],
#  ['얼라인드', '사업', '개요', '요약', '해', '줘'],
#  ['에스맥', '사업', '개요', '요약', '해', '봐'],
#  ['LG', '시가총액', '이', '궁금', '해'],
#  ['엘엠에스', '저', '가', '알려줘'],
#  ['시큐센', '와', '비슷', '한', '주식', '알려줘'],
#  ['쎄니트', '변화', '율'],
#  ['KMH하이텍', '와', '비슷', '한', '주식'],
#  ['동양고속', '변화', '율'],
#  ['일동홀딩스', '사업', '개요', '제공', '해'],
#  ['현대차우', '사업', '개요', '제공', '해', '줘'],
#  ['모베이스', '와', '비슷', '한', '항목', '보여줘'],
#  ['엠젠플러스', '요즘', '얼마', '야', '?'],
#  ['유니온머티리얼', '사업', '개요', '가', '어떻게', '돼', '?'],
#  ['엘티씨', '랑', '비슷', '한', '항목', '모', '야', '?'],
#  ['바이오코아', '변화', '율', '이', '몇', '이', '야', '?'],
#  ['엑세스바이오', '변화', '율', '은', '?'],
#  ['코리아에셋투자증권', '고가', '가', '어떻게', '돼', '?'],
#  ['한국단자', '시', '가', '말', '해'],
#  ['선바이오', '변화', '율', '이', '몇', '이', '야', '?'],
#  ['에스피시스템스', '의', '유사', '종목', '은', '모야'],
#  ['에스에프에이', '시가총액', '궁금', '해'],
#  ['원익홀딩스', '사업', '개요', '요약', '해'],
#  ['덕양산업', '랑', '비슷', '한', '항목', '이', '모', '야', '?'],
#  ['LF', 'P', '연관', '주', '보여줘'],
#  ['삼화콘덴서', '의', '유사', '종목', '열람'],
#  ['코위버', '와', '비슷', '한', '항목', '열람'],
#  ['동아타이어', '사업', '개요', '요약', '해', '바'],
#  ['정상제이엘에스', '변화', '율', '얼마', '야', '?'],
#  ['SI', 'MPAC', '와', '비슷', '한', '주식', '알려줘'],
#  ['아이디스', '랑', '비슷', '한', '항목', '은', '뭐', '가', '있', '어', '?'],
#  ['미래에셋대우', '시', '가', '얼마', '냐'],
#  ['코디엠', '변화', '율', '이', '궁금', '해', '?'],
#  ['클리오', '시가총액', '알려줘'],
#  ['세이브존I&C', '시가총액', '궁금', '해'],
#  ['한국제7호스팩', '와', '유사', '종목', '은', '뭐', '가', '있', '어', '?'],
#  ['서남', '랑', '비슷', '한', '항목', '이', '모야'],
#  ['국제약품', '랑', '비슷', '한', '항목', '모', '야', '?'],
#  ['에스피지', '얼마', '야', '?'],
#  ['현대리바트', '사업', '개요', '알려줘'],
#  ['창해에탄올', '저', '가', '알려줘'],
#  ['이월드', '시가총액', '볼래'],
#  ['드림텍', '의', '유사', '종목', '열람'],
#  ['다원넥스뷰', '사업', '개요', '요약', '해', '봐'],
#  ['컴퍼니케이', '의', '유사', '종목'],
#  ['한일시멘트', '사업', '개요', '요약', '해', '줘'],
#  ['SV인베스트먼트', '사업', '개요', '요약', '해', '봐'],
#  ['세아제강지주', '의', '유사', '종목'],
#  ['경남바이오파마', '의', '유사', '종목'],
#  ['도쿄중소형오피스1', '와', '비슷', '한', '주식', '보여줘'],
#  ['케이씨에스', '저', '가', '알려줘'],
#  ['뿌리깊은나무들', '랑', '비슷', '한', '항목', '모야'],
#  ['대신Japan하임03호A', '저', '가', '알려줘'],
#  ['한국프랜지', '사업', '개요', '볼래'],
#  ['현대백화점', '랑', '비슷', '한', '주식', '모', '야', '?'],
#  ['진흥기업2우B', '저', '가', '알려줘'],
#  ['모바일리더', '저', '가'],
#  ['대동고려삼', '얼마', '야', '?'],
#  ['하나대체일본부동산1호 C-W', '의', '유사', '종목', '은', '모', '야', '?'],
#  ['이라이콤', '고가', '얼마', '야', '?'],
#  ['드래곤플라이', '시가', '가', '어떻게', '돼', '?'],
#  ['아모텍', '시', '가', '얼마', '냐'],
#  ['가상현실', '랑', '연관', '된', '주식'],
#  ['유니슨', '시', '가', '얼마', '냐'],
#  ['골프', '랑', '관련', '된', '주식', '뭐', '있', '어', '?'],
#  ['엑스큐어', '사업', '개요', '요약', '해', '봐'],
#  ['오스테오닉', '시', '가', '말', '해'],
#  ['비디아이', '와', '비슷', '한', '주식'],
#  ['오르비텍', '고가', '가', '어떻게', '돼', '?'],
#  ['와이즈버즈', '와', '비슷', '한', '항목', '보여줘'],
#  ['쌍용양회우', '사업', '개요', '요약', '해', '바'],
#  ['에이치엔에스하이텍', '시가'],
#  ['이미지스', '의', '유사', '종목'],
#  ['한미약품', '사업', '개요', '요약', '해', '줘'],
#  ['KCI', '와', '비슷', '한', '주식'],
#  ['천보', '시가총액', '볼래'],
#  ['삼성물산', '시가총액', '보여줘'],
#  ['JW중외제약2우B', '고가', '말', '해'],
#  ...]

# %%
print('question의 최대 길이:', max(map(len, data_x)))
print('question의 평균 길이:', sum(map(len, data_x)) / len(data_x))

plt.hist([len(s) for s in data_x], bins = 50)
plt.xlabel('length of questions')
plt.ylabel('number of questions')
plt.show()
# Out:
# question의 최대 길이: 14
# question의 평균 길이: 5.4556424974675926

# %%
max_len = 12

# %%
tokenizer = Tokenizer()
tokenizer.fit_on_texts(data_x)
x_data = tokenizer.texts_to_sequences(data_x)
x_data = pad_sequences(x_data, maxlen = max_len)
print(x_data)
# Out:
# [[ 0  0  0 ... 23  5  1]
#  [ 0  0  0 ... 40  5 41]
#  [ 0  0  0 ... 23  5  1]
#  ...
#  [ 0  0  0 ...  2 11 14]
#  [ 0  0  0 ... 48 38 11]
#  [ 0  0  0 ...  6  7 44]]

# %% [markdown]
# ### train, test 데이터로 분리

# %%
x_train, x_test, y_train, y_test = train_test_split(x_data, label_data, test_size = .2, random_state = 42)

# %%
# x_train, x_test : 0-padding sequence data
# y_train, y_test : label data
x_train.shape, x_test.shape, y_train.shape, y_test.shape
# Out:
# ((163480, 12), (40871, 12), (163480,), (40871,))

# %% [markdown]
# #### y_train, y_test data one-hot encoding

# %%
y_train = to_categorical(y_train, num_classes = intent_label_size)
y_test = to_categorical(y_test, num_classes = intent_label_size)

# %%
vocab_size = len(tokenizer.word_index) + 1
vocab_size
# Out:
# 3139

# %% [markdown]
# ### Tokenizer 저장

# %%
pwd
# Out:
# '/Users/thkim/Documents/git/NLP/NLP_pjt'

# %%
import pickle

with open("intent_tokenizer.pickle", "wb") as handle:
    pickle.dump(tokenizer, handle, protocol= pickle.HIGHEST_PROTOCOL)

# %%
with open('intent_tokenizer.pickle', 'rb') as handle:
    loaded_tokenizer = pickle.load(handle)

# %% [markdown]
# ## 개체명 인식 데이터 생성

# %% [markdown]
# ### 사업개요 학습 데이터 생성
# - 가격 : PRI
# - 키워드 : KEY
# - 종목 이름 : STK
# - 나머지 : O

# %%
print(outline_df.head())
# Out:
#           question intent
# 0       동화약품 사업 개요   사업개요
# 1    동화약품 사업 개요 요약   사업개요
# 2  동화약품 사업 개요 요약해봐   사업개요
# 3  동화약품 사업 개요 요약해바   사업개요
# 4   동화약품 사업 개요 요약해   사업개요

# %%
from tqdm import tqdm

tokenized_sequences = []
label_sequences = []

for question in tqdm(outline_df['question'].to_list()):
    temp_question = []
    tokenized_question = mecab.morphs(question)
    for word in tokenized_question:
        if word in outline_not_stockname_list:
            temp_question.append('O')
        else:
            if 'B-STK' in temp_question:
                temp_question.append('I-STK')
            else:
                temp_question.append('B-STK')
                
    if 'O' not in temp_question:
        temp_question[-1] = 'O'
        temp_question[-2] = 'O'
        print('예기치 못한 레이블링 에러 발생으로 레이블 조정')
        print('조정 결과:', tokenized_question, temp_question)
    tokenized_sequences.append(tokenized_question)
    label_sequences.append(temp_question)
# Out:
# 100%|██████████████████████████████████| 56958/56958 [00:00<00:00, 59478.27it/s]

# %%
outline_df['tokenized_sample'] = tokenized_sequences
outline_df['ner_label'] = label_sequences

outline_df.sample(10)
# Out:
#                    question intent            tokenized_sample  \
# 38032        한국자산신탁 시가총액 볼래   사업개요          [한국자산신탁, 시가총액, 볼래]
# 31053    크리스탈지노믹스 사업 개요 궁금해   사업개요   [크리스탈지노믹스, 사업, 개요, 궁금, 해]
# 4853       방림 사업 개요가 어떻게 돼?   사업개요  [방림, 사업, 개요, 가, 어떻게, 돼, ?]
# 32326     THE E&M 사업 개요 보여줘   사업개요      [THE E&M, 사업, 개요, 보여줘]
# 22407         우리로 사업 개요 궁금해   사업개요      [우리, 로, 사업, 개요, 궁금, 해]
# 56122  이지스코어부동산제117호F 사업 개요   사업개요    [이지스코어부동산제117호F, 사업, 개요]
# 52443      슈프리마아이디 시가총액 알려줘   사업개요        [슈프리마아이디, 시가총액, 알려줘]
# 51022      씨에스베어링 사업 개요 요약해   사업개요     [씨에스베어링, 사업, 개요, 요약, 해]
# 40242        하이로닉 사업 개요 요약해   사업개요       [하이로닉, 사업, 개요, 요약, 해]
# 48152           수젠텍 시가총액 볼래   사업개요             [수젠텍, 시가총액, 볼래]
#
#                         ner_label
# 38032               [B-STK, O, O]
# 31053         [B-STK, O, O, O, O]
# 4853    [B-STK, O, O, O, O, O, O]
# 32326            [B-STK, O, O, O]
# 22407  [B-STK, I-STK, O, O, O, O]
# 56122               [B-STK, O, O]
# 52443               [B-STK, O, O]
# 51022         [B-STK, O, O, O, O]
# 40242         [B-STK, O, O, O, O]
# 48152               [B-STK, O, O]

# %% [markdown]
# ### 키워드 검색 학습 데이터 생성

# %%
tokenized_sequences = []
label_sequences = []

for question in keyword_df['question'].to_list():
    temp_question = []
    tokenized_question = mecab.morphs(question)
    for word in tokenized_question:
        if word in not_keyword_list:
            temp_question.append('O')
        else:
            if 'B-KEY' in temp_question:
                temp_question.append('I-KEY')
            else:
                temp_question.append('B-KEY')
                
    tokenized_sequences.append(tokenized_question)
    label_sequences.append(temp_question)

# %%
keyword_df["tokenized_sample"] = tokenized_sequences
keyword_df["ner_label"] = label_sequences

keyword_df.sample(10)
# Out:
#                 question intent                  tokenized_sample  \
# 1162       모바일게임랑 관련된 주식    키워드             [모바일게임, 랑, 관련, 된, 주식]
# 8301  강관업체랑 관련된 주식 뭐 있어?    키워드  [강관업체, 랑, 관련, 된, 주식, 뭐, 있, 어, ?]
# 4763     수소차랑 연관되 주식 알려줘    키워드          [수소차, 랑, 연관, 되, 주식, 알려줘]
# 5631           장비 연관주 검색    키워드                   [장비, 연관, 주, 검색]
# 8699    방위산업랑 연관되 주식 알려줘    키워드         [방위산업, 랑, 연관, 되, 주식, 알려줘]
# 7146          은행랑 관련된 주식    키워드                [은행, 랑, 관련, 된, 주식]
# 6249     IT랑 관련된 주 모 있어?    키워드     [IT, 랑, 관련, 된, 주, 모, 있, 어, ?]
# 3935        KIOSK 연관주 검색    키워드                [KIOSK, 연관, 주, 검색]
# 2718  증강현실랑 연관된 주식 모 있어?    키워드  [증강현실, 랑, 연관, 된, 주식, 모, 있, 어, ?]
# 2519      메신저랑 연관된 주 보여줘    키워드           [메신저, 랑, 연관, 된, 주, 보여줘]
#
#                             ner_label
# 1162              [B-KEY, O, O, O, O]
# 8301  [B-KEY, O, O, O, O, O, O, O, O]
# 4763           [B-KEY, O, O, O, O, O]
# 5631                 [B-KEY, O, O, O]
# 8699           [B-KEY, O, O, O, O, O]
# 7146              [B-KEY, O, O, O, O]
# 6249  [B-KEY, O, O, O, O, O, O, O, O]
# 3935                 [B-KEY, O, O, O]
# 2718  [B-KEY, O, O, O, O, O, O, O, O]
# 2519           [B-KEY, O, O, O, O, O]

# %% [markdown]
# ### 유사기업 학습 데이터 생성

# %%
tokenized_sequences = []
label_sequences = []

for question in similarity_df['question'].to_list():
    temp_question = []
    tokenized_question = mecab.morphs(question)
    for word in tokenized_question:
        if word in similarity_not_stock_name_list:
            temp_question.append('O')
        else:
            if 'B-STK' in temp_question:
                temp_question.append('I-STK')
            else:
                temp_question.append('B-STK')
                
    tokenized_sequences.append(tokenized_question)
    label_sequences.append(temp_question)

# %%
similarity_df['tokenized_sample'] = tokenized_sequences
similarity_df['ner_label'] = label_sequences

similarity_df.sample(10)
# Out:
#                      question intent  \
# 50001          서전기전의 유사 종목 열람   유사기업
# 26245  한일네트웍스랑 비슷한 항목은 뭐가 있어?   유사기업
# 38884      S&K폴리텍랑 비슷한 항목이 모야   유사기업
# 57487         유틸렉스의 유사 종목 보여줘   유사기업
# 55266   에스트래픽랑 비슷한 항목은 뭐가 있어?   유사기업
# 6369         NPC랑 비슷한 주식이 모야?   유사기업
# 17623     CNH랑 비슷한 주식은 뭐가 있어?   유사기업
# 37298        네오티스랑 비슷한 항목이 모야   유사기업
# 48762        라이온켐텍랑 비슷한 항목 모야   유사기업
# 14630       태경비케이와 비슷한 주식 보여줘   유사기업
#
#                                tokenized_sample  \
# 50001                     [서전기전, 의, 유사, 종목, 열람]
# 26245  [한일네트웍스, 랑, 비슷, 한, 항목, 은, 뭐, 가, 있, 어, ?]
# 38884             [S&K폴리텍, 랑, 비슷, 한, 항목, 이, 모야]
# 57487                    [유틸렉스, 의, 유사, 종목, 보여줘]
# 55266   [에스트래픽, 랑, 비슷, 한, 항목, 은, 뭐, 가, 있, 어, ?]
# 6369            [NPC, 랑, 비슷, 한, 주식, 이, 모, 야, ?]
# 17623     [CNH, 랑, 비슷, 한, 주식, 은, 뭐, 가, 있, 어, ?]
# 37298               [네오티스, 랑, 비슷, 한, 항목, 이, 모야]
# 48762                 [라이온켐텍, 랑, 비슷, 한, 항목, 모야]
# 14630                [태경비케이, 와, 비슷, 한, 주식, 보여줘]
#
#                                    ner_label
# 50001                    [B-STK, O, O, O, O]
# 26245  [B-STK, O, O, O, O, O, O, O, O, O, O]
# 38884              [B-STK, O, O, O, O, O, O]
# 57487                    [B-STK, O, O, O, O]
# 55266  [B-STK, O, O, O, O, O, O, O, O, O, O]
# 6369         [B-STK, O, O, O, O, O, O, O, O]
# 17623  [B-STK, O, O, O, O, O, O, O, O, O, O]
# 37298              [B-STK, O, O, O, O, O, O]
# 48762                 [B-STK, O, O, O, O, O]
# 14630                 [B-STK, O, O, O, O, O]

# %% [markdown]
# ### 가격 학습 데이터 생성

# %%
tokenized_sequences = []
label_sequences = []

for question in price_df['question']:
    temp_question = []
    tokenized_question = mecab.morphs(question)
    for word in tokenized_question:
        if word in stk_price_not_stock_name_list:
            if word in {'가격', '종가', '저가', '고가', '시가', '변화율', '변화', '율', '고','시', '저', '가'}:
                if 'B-PRI' in temp_question:
                    temp_question.append('I-PRI')
                else:
                    temp_question.append('B-PRI')
            else:
                temp_question.append('O')
        else:
            if 'B-STK' in temp_question:
                temp_question.append('I-STK')
            else:
                temp_question.append('B-STK')
                
    tokenized_sequences.append(tokenized_question)
    label_sequences.append(temp_question)

# %%
price_df['tokenized_sample'] = tokenized_sequences
price_df['ner_label'] = label_sequences

price_df.sample(10)
# Out:
#                question intent                tokenized_sample  \
# 27389     삼화네트웍스 종가 얼마냐     가격             [삼화네트웍스, 종가, 얼마, 냐]
# 16730        광전자 시가 얼마냐     가격              [광전자, 시, 가, 얼마, 냐]
# 20732  에스에이엠티 변화율이 몇이야?     가격  [에스에이엠티, 변화, 율, 이, 몇, 이, 야, ?]
# 66568   제이알글로벌리츠 저가 알려줘     가격           [제이알글로벌리츠, 저, 가, 알려줘]
# 25615       에버다임 저가 알려줘     가격               [에버다임, 저, 가, 알려줘]
# 26619     서울리거 변화율 얼마야?     가격         [서울리거, 변화, 율, 얼마, 야, ?]
# 63164     바이브컴퍼니 종가 얼마냐     가격             [바이브컴퍼니, 종가, 얼마, 냐]
# 66585       이베스트스팩5호 시가     가격                  [이베스트스팩5호, 시가]
# 12849      오리콤 변화율 얼마야?     가격          [오리콤, 변화, 율, 얼마, 야, ?]
# 15038    금강공업 변화율이 궁금해?     가격      [금강공업, 변화, 율, 이, 궁금, 해, ?]
#
#                                   ner_label
# 27389                  [B-STK, B-PRI, O, O]
# 16730           [B-STK, B-PRI, I-PRI, O, O]
# 20732  [B-STK, B-PRI, I-PRI, O, O, O, O, O]
# 66568              [B-STK, B-PRI, I-PRI, O]
# 25615              [B-STK, B-PRI, I-PRI, O]
# 26619        [B-STK, B-PRI, I-PRI, O, O, O]
# 63164                  [B-STK, B-PRI, O, O]
# 66585                        [B-STK, B-PRI]
# 12849        [B-STK, B-PRI, I-PRI, O, O, O]
# 15038     [B-STK, B-PRI, I-PRI, O, O, O, O]

# %% [markdown]
# ### 개체명 인식 데이터 생성 및 저장

# %%
ner_df = similarity_df.copy()
ner_df = ner_df.append(keyword_df).append(outline_df).append(price_df)

ner_df
# Out:
# /var/folders/bg/yxv_kcpd4wl8ysqfd1pnwdt00000gn/T/ipykernel_8739/497301404.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   ner_df = ner_df.append(keyword_df).append(outline_df).append(price_df)
# /var/folders/bg/yxv_kcpd4wl8ysqfd1pnwdt00000gn/T/ipykernel_8739/497301404.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   ner_df = ner_df.append(keyword_df).append(outline_df).append(price_df)
#                    question intent                     tokenized_sample  \
# 0               동화약품의 유사 종목   유사기업                    [동화약품, 의, 유사, 종목]
# 1           동화약품의 유사 종목 보여줘   유사기업               [동화약품, 의, 유사, 종목, 보여줘]
# 2           동화약품의 유사 종목 알려줘   유사기업               [동화약품, 의, 유사, 종목, 알려줘]
# 3            동화약품의 유사 종목 열람   유사기업                [동화약품, 의, 유사, 종목, 열람]
# 4       동화약품와 유사 종목은 뭐가 있어?   유사기업  [동화약품, 와, 유사, 종목, 은, 뭐, 가, 있, 어, ?]
# ...                     ...    ...                                  ...
# 69898   소마젠(Reg.S) 변화율 몇이야?     가격      [소마젠(Reg.S), 변화, 율, 몇, 이, 야, ?]
# 69899  소마젠(Reg.S) 변화율이 몇이야?     가격   [소마젠(Reg.S), 변화, 율, 이, 몇, 이, 야, ?]
# 69900   소마젠(Reg.S) 변화율 얼마야?     가격        [소마젠(Reg.S), 변화, 율, 얼마, 야, ?]
# 69901    소마젠(Reg.S) 변화율 궁금해     가격           [소마젠(Reg.S), 변화, 율, 궁금, 해]
# 69902  소마젠(Reg.S) 변화율이 궁금해?     가격     [소마젠(Reg.S), 변화, 율, 이, 궁금, 해, ?]
#
#                                   ner_label
# 0                          [B-STK, O, O, O]
# 1                       [B-STK, O, O, O, O]
# 2                       [B-STK, O, O, O, O]
# 3                       [B-STK, O, O, O, O]
# 4        [B-STK, O, O, O, O, O, O, O, O, O]
# ...                                     ...
# 69898     [B-STK, B-PRI, I-PRI, O, O, O, O]
# 69899  [B-STK, B-PRI, I-PRI, O, O, O, O, O]
# 69900        [B-STK, B-PRI, I-PRI, O, O, O]
# 69901           [B-STK, B-PRI, I-PRI, O, O]
# 69902     [B-STK, B-PRI, I-PRI, O, O, O, O]
#
# [204351 rows x 4 columns]

# %%
# pip install tables
# Out:
# Collecting tables
#   Downloading tables-3.7.0.tar.gz (8.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.2/8.2 MB 9.9 MB/s eta 0:00:000m eta 0:00:010:01:01
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: packaging in /opt/homebrew/Caskroom/miniforge/base/envs/tf25/lib/python3.8/site-packages (from tables) (21.3)
# Collecting numexpr>=2.6.2
#   Downloading numexpr-2.8.1.tar.gz (94 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 94.8/94.8 KB 3.1 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: numpy>=1.19.0 in /opt/homebrew/Caskroom/miniforge/base/envs/tf25/lib/python3.8/site-packages (from tables) (1.22.2)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/homebrew/Caskroom/miniforge/base/envs/tf25/lib/python3.8/site-packages (from packaging->tables) (3.0.7)
# Building wheels for collected packages: tables, numexpr
#   Building wheel for tables (pyproject.toml) ... done
#   Created wheel for tables: filename=tables-3.7.0-cp38-cp38-macosx_11_0_arm64.whl size=3697153 sha256=039fd7fc826c4a83d3fe2ef49544c5db6c428b20b41ce75cf6690e1fba5dcfe3
#   Stored in directory: /Users/thkim/Library/Caches/pip/wheels/45/d2/09/c181c2eb9ec01a0097196b3fd95a57cb3a3c75f248cf587a55
#   Building wheel for numexpr (pyproject.toml) ... done
#   Created wheel for numexpr: filename=numexpr-2.8.1-cp38-cp38-macosx_11_0_arm64.whl size=88292 sha256=8d18ec5593a5586622d93705309f4348d109ff4018f898ed15fa5e8b64998050
#   Stored in directory: /Users/thkim/Library/Caches/pip/wheels/23/d8/5d/5d71d7aeee2da6c0657a2d20fcd45746b59cbfdd194e62f630
# Successfully built tables numexpr
# Installing collected packages: numexpr, tables
# Successfully installed numexpr-2.8.1 tables-3.7.0
# Note: you may need to restart the kernel to use updated packages.

# %%
ner_df.to_hdf('../ner_data.h5', key = 'df', mode = 'w')
# Out:
# /var/folders/bg/yxv_kcpd4wl8ysqfd1pnwdt00000gn/T/ipykernel_8739/2190570957.py:1: PerformanceWarning:
# your performance may suffer as PyTables will pickle object types that it cannot
# map directly to c-types [inferred_type->mixed,key->block0_values] [items->Index(['question', 'intent', 'tokenized_sample', 'ner_label'], dtype='object')]
#
#   ner_df.to_hdf('../ner_data.h5', key = 'df', mode = 'w')

# %%
temp = pd.read_hdf('../ner_data.h5', 'df')
temp.head()
# Out:
#               question intent                     tokenized_sample  \
# 0          동화약품의 유사 종목   유사기업                    [동화약품, 의, 유사, 종목]
# 1      동화약품의 유사 종목 보여줘   유사기업               [동화약품, 의, 유사, 종목, 보여줘]
# 2      동화약품의 유사 종목 알려줘   유사기업               [동화약품, 의, 유사, 종목, 알려줘]
# 3       동화약품의 유사 종목 열람   유사기업                [동화약품, 의, 유사, 종목, 열람]
# 4  동화약품와 유사 종목은 뭐가 있어?   유사기업  [동화약품, 와, 유사, 종목, 은, 뭐, 가, 있, 어, ?]
#
#                             ner_label
# 0                    [B-STK, O, O, O]
# 1                 [B-STK, O, O, O, O]
# 2                 [B-STK, O, O, O, O]
# 3                 [B-STK, O, O, O, O]
# 4  [B-STK, O, O, O, O, O, O, O, O, O]

# %% [markdown]
# ### ner_df 데이터 구조 시각화

# %%
ner_sentences = ner_df['tokenized_sample'].to_list()
ner_tags = ner_df['ner_label'].to_list()

# %%
print('샘플의 최대 길이 : %d' % max(len(l) for l in ner_sentences))
print('샘플의 평균 길이 : %f' % (sum(map(len, ner_sentences))/len(ner_sentences)))
plt.hist([len(s) for s in ner_sentences], bins=50)
plt.xlabel('length of samples')
plt.ylabel('number of samples')
plt.show()
# Out:
# 샘플의 최대 길이 : 14
# 샘플의 평균 길이 : 5.455642

# %% [markdown]
# ### 개체명 인식 데이터 Tokenizing

# %%
# 모든 단어를 사용하지만, Index 1에는 'Out of Vocabulary' 할당
src_tokenizer = Tokenizer(oov_token = 'OOV')
src_tokenizer.fit_on_texts(ner_sentences)
# Tagging 정보들은 내부적으로 대문자를 유지한채로 저장
tar_tokenizer = Tokenizer(lower = False)
tar_tokenizer.fit_on_texts(ner_tags)

# %%
vocab_size = len(src_tokenizer.word_index) + 1
tag_size = len(tar_tokenizer.word_index) + 1
print('단어 집합의 크기: {}'.format(vocab_size))
print('개체명 태깅 정보 집합의 크기: {}'.format(tag_size))
# Out:
# 단어 집합의 크기: 3140
# 개체명 태깅 정보 집합의 크기: 8

# %%
print('단어 OOV의 인덱스: {}'.format(src_tokenizer.word_index['OOV']))
# Out:
# 단어 OOV의 인덱스: 1

# %%
x_data = src_tokenizer.texts_to_sequences(ner_sentences)
y_data = tar_tokenizer.texts_to_sequences(ner_tags)

# %%
print(x_data[0], y_data[0])
# Out:
# [121, 24, 18, 19] [2, 1, 1, 1]

# %%
word_to_index = src_tokenizer.word_index
index_to_word = src_tokenizer.index_word
ner_to_index = tar_tokenizer.word_index
index_to_ner = tar_tokenizer.index_word
index_to_ner[0] = 'PAD'
index_to_ner
# Out:
# {1: 'O',
#  2: 'B-STK',
#  3: 'B-PRI',
#  4: 'I-PRI',
#  5: 'B-KEY',
#  6: 'I-STK',
#  7: 'I-KEY',
#  0: 'PAD'}

# %%
decoded = []
for index in x_data[0]:
    decoded.append(index_to_word[index])
    
print('기존의 문장: {}'.format(ner_sentences[0]))
print('디코딩 문장: {}'.format(decoded))
# Out:
# 기존의 문장: ['동화약품', '의', '유사', '종목']
# 디코딩 문장: ['동화약품', '의', '유사', '종목']

# %%
max_len = 12
x_data = pad_sequences(x_data, padding = 'post', maxlen = max_len)
y_data = pad_sequences(y_data, padding = 'post', maxlen = max_len)

# %%
x_train, x_test, y_train, y_test = train_test_split(x_data, y_data, test_size = .2, random_state = 777)

# %%
y_train = to_categorical(y_train, num_classes = tag_size)
y_test = to_categorical(y_test, num_classes = tag_size)

# %%
print('훈련 샘플 문장의 크기 : {}'.format(x_train.shape))
print('훈련 샘플 레이블의 크기 : {}'.format(y_train.shape))
print('테스트 샘플 문장의 크기 : {}'.format(x_test.shape))
print('테스트 샘플 레이블의 크기 : {}'.format(y_test.shape))
# Out:
# 훈련 샘플 문장의 크기 : (163480, 12)
# 훈련 샘플 레이블의 크기 : (163480, 12, 8)
# 테스트 샘플 문장의 크기 : (40871, 12)
# 테스트 샘플 레이블의 크기 : (40871, 12, 8)

# %%
with open('ner_src_tokenizer.pickle', 'wb') as handle:
    pickle.dump(src_tokenizer, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %%
with open('ner_tar_tokenizer.pickle', 'wb') as handle:
    pickle.dump(tar_tokenizer, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %%
# pip install seqeval
# Out:
# Collecting seqeval
#   Downloading seqeval-1.2.2.tar.gz (43 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.6/43.6 KB 1.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy>=1.14.0 in /opt/homebrew/Caskroom/miniforge/base/envs/tf25/lib/python3.8/site-packages (from seqeval) (1.22.2)
# Requirement already satisfied: scikit-learn>=0.21.3 in /opt/homebrew/Caskroom/miniforge/base/envs/tf25/lib/python3.8/site-packages (from seqeval) (1.0.2)
# Requirement already satisfied: scipy>=1.1.0 in /opt/homebrew/Caskroom/miniforge/base/envs/tf25/lib/python3.8/site-packages (from scikit-learn>=0.21.3->seqeval) (1.8.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/homebrew/Caskroom/miniforge/base/envs/tf25/lib/python3.8/site-packages (from scikit-learn>=0.21.3->seqeval) (3.1.0)
# Requirement already satisfied: joblib>=0.11 in /opt/homebrew/Caskroom/miniforge/base/envs/tf25/lib/python3.8/site-packages (from scikit-learn>=0.21.3->seqeval) (1.1.0)
# Building wheels for collected packages: seqeval
#   Building wheel for seqeval (setup.py) ... done
#   Created wheel for seqeval: filename=seqeval-1.2.2-py3-none-any.whl size=16181 sha256=3df48009a6887aa46db558effa2a926c14507210f85b878a7e0e211f208cf8fc
#   Stored in directory: /Users/thkim/Library/Caches/pip/wheels/ad/5c/ba/05fa33fa5855777b7d686e843ec07452f22a66a138e290e732
# Successfully built seqeval
# Installing collected packages: seqeval
# Successfully installed seqeval-1.2.2
# Note: you may need to restart the kernel to use updated packages.

# %%
from keras.callbacks import Callback
from seqeval.metrics import f1_score, classification_report

# %%
class F1score(Callback):
    def __init__(self, value = 0.0, use_char=True):
        super(F1score, self).__init__()
        self.value = value
        self.use_char = use_char

    def sequences_to_tags(self, sequences): # 예측값을 index_to_ner를 사용하여 태깅 정보로 변경하는 함수.
        result = []
        for sequence in sequences: # 전체 시퀀스로부터 시퀀스를 하나씩 꺼낸다.
            tag = []
            for pred in sequence: # 시퀀스로부터 예측값을 하나씩 꺼낸다.
                pred_index = np.argmax(pred) # 예를 들어 [0, 0, 1, 0 ,0]라면 1의 인덱스인 2를 리턴한다.
                tag.append(index_to_ner[pred_index].replace("PAD", "O")) # 'PAD'는 'O'로 변경
            result.append(tag)
        return result

    # 에포크가 끝날 때마다 실행되는 함수
    def on_epoch_end(self, epoch, logs={}):

      # char Embedding을 사용하는 경우
        if self.use_char:
            X_test = self.validation_data[0]
            X_char_test = self.validation_data[1]
            y_test = self.validation_data[2]
            y_predicted = self.model.predict([X_test, X_char_test])

        else:
            X_test = self.validation_data[0]
            y_test = self.validation_data[1]
            y_predicted = self.model.predict([X_test])

        pred_tags = self.sequences_to_tags(y_predicted)
        test_tags = self.sequences_to_tags(y_test)

        score = f1_score(pred_tags, test_tags)
        print(' - f1: {:04.2f}'.format(score * 100))
        print(classification_report(test_tags, pred_tags))

      # F1-score가 지금까지 중 가장 높은 경우
        if score > self.value:
            print('f1_score improved from %f to %f, saving model to best_model.h5'%(self.value, score))
            self.model.save('ner_crf_best_model.h5')
            self.value = score
        else:
            print('f1_score did not improve from %f'%(self.value))

# %%
ls data
# Out:
# dart_data_path.txt  intent_data.csv     ner_data.h5         stock_names.csv
